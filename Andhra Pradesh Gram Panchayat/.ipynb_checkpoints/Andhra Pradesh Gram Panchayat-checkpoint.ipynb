# %% [markdown]
# # Codebook
# **Authors:** Patriccolumn = AndhraPradeshGramPanchayat["Mandal"]
# columnk Guo
# Documenting existing data files of DaanMatch with information about location, owner, "version", source etc.

# %%
import boto3
import pandas as pd
import numpy as np 
import os
from collections import Counter
import matplotlib.pyplot as plt
import statistics
import operator

# %%
client = boto3.client('s3')
resource = boto3.resource('s3')
my_bucket = resource.Bucket('my-bucket')

# %% [markdown]
# # Andhra_Pradesh_Gram_Panchayat
#
# ## TOC:
# * [About this dataset](#1)
# * [What's in this dataset](#2)
# * [Codebook](#3)
#     * [Missing values](#3.1)
#     * [Summary statistics](#3.2)
# * [Columns](#4)
#     * [S. No.](#4.1)
#     * [District](#4.2)
#     * [Mandal](#4.3)
#     * [Panchayat](#4.4)
#     * [Gram Panchayat Special officer Name](#4.5)
#     * [Mobile Number](#4.6)
#     * [Address for Communication](#4.7)

# %% [markdown]
# **About this dataset**  <a class="anchor" id="1"></a>
# Data provided by: The Ministry of Panchayati Raj
# Source: https://www.panchayat.gov.in/documents/20126/75657/Andhra+Pradesh+Gram+Panchayat.xlsx/e1b39a3d-d726-fd91-68c8-3d7cd42755a4?t=1556532428214
# Type: xlsx
# Last modified: May 29, 2021, 19:53:36 (UTC-07:00)
# Size: 894.3 KB

# %%
path = "s3://daanmatchdatafiles/DaanMatch_DataFiles/Andhra Pradesh Gram Panchayat.xlsx"
xl = pd.ExcelFile(path)
print(xl.sheet_names)
# Load sheet
AndhraPradeshGramPanchayat = xl.parse("Gram Panchayat")
# Reset index
AndhraPradeshGramPanchayat.head()
# Out:
# ['Gram Panchayat']
#    S. No.    District      Mandal        Panchayat  \
# 0       1  Ananthapur  Ananthapur  A.Narayanapuram
# 1       2  Ananthapur  Ananthapur    Akuthotapalli
# 2       3  Ananthapur  Ananthapur          Alamuru
# 3       4  Ananthapur  Ananthapur     Anantapur(R)
# 4       5  Ananthapur  Ananthapur       Ankampalli
#
#   Gram Panchayat Special officer Name  Mobile Number  \
# 0                         Anwar Basha   9.496189e+09
# 1                          C Obulamma   9.490610e+09
# 2                              SURESH   8.790998e+09
# 3                           H M Basha   9.703327e+09
# 4                P Venkatesh Kumar      9.985021e+09
#
#                            Address for Communication
# 0  Sarpanch\nA.Narayanapuram Gram Panchayat \nAt-...
# 1  Sarpanch\nAkuthotapalli Gram Panchayat \nAt- A...
# 2  Sarpanch\nAlamuru Gram Panchayat \nAt- Alamuru...
# 3  Sarpanch\nAnantapur(R) Gram Panchayat \nAt- An...
# 4  Sarpanch\nAnkampalli Gram Panchayat \nAt- Anka...

# %% [markdown]
# **What's in this dataset?** <a class="anchor" id="2"></a>

# %%
print("Shape:", AndhraPradeshGramPanchayat.shape)
print("Rows:", AndhraPradeshGramPanchayat.shape[0])
print("Columns:", AndhraPradeshGramPanchayat.shape[1])
print("Each row is a Gram Panchayat.")
# Out:
# Shape: (12918, 7)
# Rows: 12918
# Columns: 7
# Each row is a Gram Panchayat.

# %%
AndhraPradeshGramPanchayat_columns = [column for column in AndhraPradeshGramPanchayat_df.columns]
AndhraPradeshGramPanchayat_columns
# Out:
# ['S. No.',
#  'District',
#  'Mandal',
#  'Panchayat',
#  'Gram Panchayat Special officer Name',
#  'Mobile Number',
#  'Address for Communication']

# %% [markdown]
# **Codebook** <a class="anchor" id="3"></a>

# %%
AndhraPradeshGramPanchayat_columns = [column for column in AndhraPradeshGramPanchayat_df.columns]
AndhraPradeshGramPanchayat_description = ["Index",
                                          "District name",
                                          "Mandal (local government area)", 
                                          "Panchayat (village)", 
                                          "Name of Gram Panchayat special officer", 
                                          "Mobile Number", 
                                          "Communication Address"]
AndhraPradeshGramPanchayat_dtypes = [dtype for dtype in AndhraPradeshGramPanchayat_df.dtypes]

data = {"Column Name": AndhraPradeshGramPanchayat_columns, "Description": AndhraPradeshGramPanchayat_description, "Type": AndhraPradeshGramPanchayat_dtypes}
AndhraPradeshGramPanchayat_codebook = pd.DataFrame(data)
AndhraPradeshGramPanchayat_codebook
# Out:
#                            Column Name  \
# 0                               S. No.
# 1                             District
# 2                               Mandal
# 3                            Panchayat
# 4  Gram Panchayat Special officer Name
# 5                        Mobile Number
# 6            Address for Communication
#
#                               Description     Type
# 0                                   Index    int64
# 1                           District name   object
# 2          Mandal (local government area)   object
# 3                     Panchayat (village)   object
# 4  Name of Gram Panchayat special officer   object
# 5                           Mobile Number  float64
# 6                   Communication Address   object

# %% [markdown]
# **Missing values** <a class="anchor" id="3.1"></a>

# %%
AndhraPradeshGramPanchayat.isnull().sum()
# Out:
# S. No.                                  0
# District                                0
# Mandal                                  0
# Panchayat                               0
# Gram Panchayat Special officer Name    17
# Mobile Number                          21
# Address for Communication               0
# dtype: int64

# %% [markdown]
# **Summary statistics** <a class="anchor" id="3.2"></a>

# %% [markdown]
# Not applicable because all are qualitative values.

# %% [markdown]
# ## Columns
# <a class="anchor" id="4"></a>

# %% [markdown]
# ### S. No.
# <a class="anchor" id="4.1"></a>
# Index

# %%
column = AndhraPradeshGramPanchayat["S. No."]
column
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 12913    12914
# 12914    12915
# 12915    12916
# 12916    12917
# 12917    12918
# Name: S. No., Length: 12918, dtype: int64

# %%
# Check for duplicates
counter = dict(Counter(column))
duplicates = { key:value for key, value in counter.items() if value > 1}
print("Duplicates:", duplicates)
# Out:
# Duplicates: {}

# %% [markdown]
# ### District
# <a class="anchor" id="4.2"></a>
# District name.
# 13 unique values.

# %%
column = AndhraPradeshGramPanchayat["District"]
column
# Out:
# 0          Ananthapur
# 1          Ananthapur
# 2          Ananthapur
# 3          Ananthapur
# 4          Ananthapur
#              ...
# 12913    YSR District
# 12914    YSR District
# 12915    YSR District
# 12916    YSR District
# 12917    YSR District
# Name: District, Length: 12918, dtype: object

# %%
print("Unique values:", column.unique())
print("No. of unique values:", len(column.unique()))

# Number of empty strings/missing values
print("Invalid:", sum(column == " ") + sum(column.isnull()))

# Table of number of each class
counter = dict(Counter(column))
count = { key:[value] for key, value in counter.items()}
table = pd.DataFrame.from_dict(count)
table = table.melt(var_name="District", value_name="Count")
table
# Out:
# Unique values: ['Ananthapur' 'Chittoor' 'East Godavari' 'Guntur' 'Krishna' 'Kurnool'
#  'Prakasam' 'SPSR Nellore' 'Srikakulam' 'Visakhapatnam' 'Vizianagaram'
#  'West Godavari' 'YSR District']
# No. of unique values: 13
# Invalid: 0
#          District  Count
# 0      Ananthapur   1003
# 1        Chittoor   1363
# 2   East Godavari   1069
# 3          Guntur   1011
# 4         Krishna    970
# 5         Kurnool    889
# 6        Prakasam   1028
# 7    SPSR Nellore    940
# 8      Srikakulam   1100
# 9   Visakhapatnam    925
# 10   Vizianagaram    921
# 11  West Godavari    909
# 12   YSR District    790

# %%
# Plot number of each class
table.plot.bar(x="District", y="Count")
ax = plt.title("Count of District")
plt.xlabel("Class")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Mandal
# <a class="anchor" id="4.3"></a>
# Mandal (local government area)
# 648 unique values

# %%
column = AndhraPradeshGramPanchayat["Mandal"]
column
# Out:
# 0        Ananthapur
# 1        Ananthapur
# 2        Ananthapur
# 3        Ananthapur
# 4        Ananthapur
#             ...
# 12913    Vontimitta
# 12914    Vontimitta
# 12915    Vontimitta
# 12916    Vontimitta
# 12917    Vontimitta
# Name: Mandal, Length: 12918, dtype: object

# %%
print("No. of unique values:", len(column.unique()))

# Number of empty strings/missing values
print("Invalid:", sum(column == " ") + sum(column.isnull()))

# Table of number of each class
counter = dict(Counter(column))
count = { key:[value] for key, value in counter.items()}
table = pd.DataFrame.from_dict(count)
table = table.melt(var_name="Mandal", value_name="Count").sort_values("Count", ascending = False)
table
# Out:
# No. of unique values: 648
# Invalid: 0
#                Mandal  Count
# 256             Gudur     59
# 275          Unguturu     54
# 177     Seethanagaram     51
# 76   Ramachandrapuram     48
# 423        Kondapuram     47
# ..                ...    ...
# 636         Gopavaram      7
# 322         Pagidyala      7
# 302    Maddikera East      7
# 94       Kurabalakota      6
# 607        Pulivendla      6
#
# [648 rows x 2 columns]

# %%
# Summary Statistics
print("Max count:", table["Count"].max())
print("Min count:", table["Count"].min())
print("Mean count:", table["Count"].mean())
print("Median count:",table["Count"].median())
print("Mode count:", table["Count"].median())
# Out:
# Max count: 59
# Min count: 6
# Mean count: 19.935185185185187
# Median count: 19.0
# Mode count: 19.0

# %% [markdown]
# ### Panchayat
# <a class="anchor" id="4.4"></a>
# Panchayat (village)
# 10878 unique values
# 1112 duplicates

# %%
column = AndhraPradeshGramPanchayat["Panchayat"]
column
# Out:
# 0        A.Narayanapuram
# 1          Akuthotapalli
# 2                Alamuru
# 3           Anantapur(R)
# 4             Ankampalli
#               ...
# 12913     Narvakatipalle
# 12914        Pennaperuru
# 12915     Rachagudipalle
# 12916            Salabad
# 12917         Vontimitta
# Name: Panchayat, Length: 12918, dtype: object

# %%
print("No. of unique values:", len(column.unique()))

# Number of empty strings/missing values
print("Invalid:", sum(column == " ") + sum(column.isnull()))


# Check for duplicates
counter = dict(Counter(column))
duplicates = { key:[value] for key, value in counter.items() if value > 1}
print("No. of Duplicates:", len(duplicates))

table = pd.DataFrame.from_dict(duplicates)
table = table.melt(var_name="Duplicate Panchayats", value_name="Count").sort_values(by=["Count"], ascending=False).reset_index(drop=True)
table
# Out:
# No. of unique values: 10878
# Invalid: 0
# No. of Duplicates: 1112
#      Duplicate Panchayats  Count
# 0            Venkatapuram     22
# 1              Kothapalli     17
# 2                 Kothuru     16
# 3              Uppalapadu     15
# 4         Jagannadhapuram     15
# ...                   ...    ...
# 1107     Ramachandrapalem      2
# 1108         Tangellamudi      2
# 1109  Venkatakrishnapuram      2
# 1110        Abbarajupalem      2
# 1111        Ananthampalli      2
#
# [1112 rows x 2 columns]

# %%
# Example
AndhraPradeshGramPanchayat[AndhraPradeshGramPanchayat["Panchayat"] == "Venkatapuram"]
# Out:
#        S. No.       District              Mandal     Panchayat  \
# 58         59     Ananthapur   Bukkarayasamudram  Venkatapuram
# 883       884     Ananthapur  Obuladevaracheruvu  Venkatapuram
# 1343     1344       Chittoor   Srirangarajapuram  Venkatapuram
# 2168     2169       Chittoor           Renigunta  Venkatapuram
# 2936     2937  East Godavari          Rangampeta  Venkatapuram
# 4536     4537        Krishna           Kalidindi  Venkatapuram
# 4831     4832        Krishna            Mopidevi  Venkatapuram
# 5216     5217        Krishna           G Konduru  Venkatapuram
# 5339     5340        Krishna     Penuganchiprolu  Venkatapuram
# 5780     5781        Kurnool               Dhone  Venkatapuram
# 6051     6052        Kurnool       Banaganapalle  Venkatapuram
# 7004     7005       Prakasam             Addanki  Venkatapuram
# 8382     8383     Srikakulam          Meilaputti  Venkatapuram
# 8575     8576     Srikakulam          Saravakota  Venkatapuram
# 8834     8835     Srikakulam              Laveru  Venkatapuram
# 9067     9068     Srikakulam            Jalumuru  Venkatapuram
# 10198   10199  Visakhapatnam          Munagapaka  Venkatapuram
# 10219   10220  Visakhapatnam         Padmanabham  Venkatapuram
# 10677   10678   Vizianagaram       Seethanagaram  Venkatapuram
# 11294   11295  West Godavari               Eluru  Venkatapuram
# 11529   11530  West Godavari        Chintalapudi  Venkatapuram
# 12069   12070  West Godavari           Palakollu  Venkatapuram
#
#       Gram Panchayat Special officer Name  Mobile Number  \
# 58                          K Damodaramma   7.382604e+09
# 883                             M Gudenna   9.703920e+09
# 1343                            R MADHURI   7.093413e+09
# 2168                       K Sudhakar Rao   9.491071e+09
# 2936                             P Ramjee   9.100121e+09
# 4536                               Skjani   7.093931e+09
# 4831                  Ch Brahmananda Babu   9.963920e+09
# 5216                         M Rama Kumar   8.886613e+09
# 5339                   K Venkateswara Rao   9.491676e+09
# 5780                     A.THIRUMALA VANI   9.849904e+09
# 6051                     Sri.Dr M.NAVEEN    8.639935e+09
# 7004                     C. HEMADRI NAIDU   7.093010e+09
# 8382                Sri K.Nageswara rao,    9.441469e+09
# 8575                         M Eswara Rao   9.492343e+09
# 8834                         S.Sudhasagar   7.036303e+09
# 9067                    Sri P.vasudevaRao   8.790008e+09
# 10198                      S.S Padmavathi   9.493800e+09
# 10219                      SMT.K.RAMADEVI   9.100065e+09
# 10677                     K Vijayalakshmi   9.491036e+09
# 11294                  Chandra sekhar rao   9.491041e+09
# 11529                  Sri P G Bucchibabu   8.886613e+09
# 12069                          4112202004   9.515159e+09
#
#                                Address for Communication
# 58     Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 883    Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 1343   Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 2168   Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 2936   Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 4536   Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 4831   Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 5216   Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 5339   Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 5780   Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 6051   Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 7004   Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 8382   Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 8575   Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 8834   Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 9067   Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 10198  Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 10219  Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 10677  Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 11294  Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 11529  Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...
# 12069  Sarpanch\nVenkatapuram Gram Panchayat \nAt- Ve...

# %% [markdown]
# Duplicate Panchayats do not mean duplicate rows.

# %% [markdown]
# ### Gram Panchayat Special officer Name
# <a class="anchor" id="4.5"></a>
# Name of Gram Panchayat special officer

# %%
column = AndhraPradeshGramPanchayat["Gram Panchayat Special officer Name"]
column
# Out:
# 0                   Anwar Basha
# 1                    C Obulamma
# 2                        SURESH
# 3                     H M Basha
# 4          P Venkatesh Kumar
#                   ...
# 12913          A.Venkata Prasad
# 12914                   Sirisha
# 12915    Sri G.Venkata Subbaiah
# 12916          A.Venkata Prasad
# 12917            Smt J.Sireesha
# Name: Gram Panchayat Special officer Name, Length: 12918, dtype: object

# %%
print("No. of unique values:", len(column.unique()))

# Number of empty strings/missing values
print("Invalid:", sum(column == " ") + sum(column.isnull()))
column = column.dropna()
# Check for duplicates
counter = dict(Counter(column))
duplicates = { key:[value] for key, value in counter.items() if value > 1}
print("No. of Duplicates:", len(duplicates))


table = pd.DataFrame.from_dict(duplicates)
table = table.melt(var_name="Duplicate Gram Panchayat Special officer Names", value_name="Count").sort_values(by=["Count"], ascending=False).reset_index(drop=True)
table
# Out:
# No. of unique values: 5847
# Invalid: 17
# No. of Duplicates: 3635
#      Duplicate Gram Panchayat Special officer Names  Count
# 0                                   G Venkateswarlu     14
# 1                                   P Venkataramana     13
# 2                                     V Swaruparani     12
# 3                               P Siva Subrahmanyam     12
# 4                                    M VIJAYA KUMAR     11
# ...                                             ...    ...
# 3630                                    N V Krishna      2
# 3631                                     Sk Hussain      2
# 3632                             S Rajeshkar  Reddy      2
# 3633                             T Rama Chadra Raju      2
# 3634                            Sri.SreenivasaReddy      2
#
# [3635 rows x 2 columns]

# %%
duplicates
# Example
#AndhraPradeshGramPanchayat[AndhraPradeshGramPanchayat["Gram Panchayat Special officer Name"] == "Alamuru"]
# Out:
# {'C Obulamma': 2,
#  'SURESH': 2,
#  'H M Basha': 2,
#  'P Venkatesh Kumar   ': 2,
#  'A Nirmala Meri': 2,
#  'PRASAD': 2,
#  'E VENKATA SWAMY': 2,
#  'M Narasaiah': 2,
#  'HEMALATHA': 2,
#  'J VASU PRAKASH': 2,
#  'K Narasimha Reddy': 2,
#  'M Siva Ramudu': 2,
#  'P Sreenivasulu': 3,
#  'A LOKESH BABU': 2,
#  'P Musthaq Ahmed Khan': 2,
#  'P Damodaraiah': 2,
#  'B Chandrakala': 2,
#  'D Peddanna': 2,
#  'Smt Chennamma': 2,
#  'Smt Vanisree': 3,
#  'G Kalyani': 2,
#  'Guru Prasad': 2,
#  'A Suresh Kumar  ': 2,
#  'K Damodaramma': 2,
#  'c nagaraju': 2,
#  'PSreenath Reddy': 2,
#  ' K Tarachandranaik': 2,
#  'S Rajyalakshmi': 2,
#  'Nageswari': 2,
#  'B V Sasikala': 2,
#  'G Prabhu Kishor': 2,
#  'P Vijayakumari': 2,
#  'K Sarada': 4,
#  'G Thippayya': 2,
#  'M C Chandra prasad': 2,
#  'K A Jalajakshi': 2,
#  'M Venkataramudu': 2,
#  'M Rajkumar': 2,
#  'C N Munivelu ': 2,
#  'K Hajivali': 2,
#  'D Siddappa': 2,
#  'RAMA KRISHNUDU BINGI': 2,
#  'B Eramma': 2,
#  'C Muralidhar': 4,
#  'Shekshavali': 2,
#  'SANKAR VADDE': 3,
#  'KULLAYAPPA KORICHA': 3,
#  'HARI PRASAD CHENNA': 2,
#  'SREEKANTH CHOWDARY G': 2,
#  'PADMAVATHI JAKKA': 2,
#  'T Lakshminarayana': 2,
#  'Chandrasekhar': 6,
#  'C V Muralidhar': 2,
#  'Nagendra': 3,
#  'D Govinda das': 2,
#  'J Solomon': 4,
#  'T K Chandrasekhar ': 2,
#  'Krishnaiah ': 2,
#  'K Sridhar Babu': 2,
#  'Venkateswaralu ': 2,
#  ' A Venkatkumar': 2,
#  'S Devanand  Kumar ': 2,
#  'S Jaya Naik': 2,
#  'R Balaji Raju': 2,
#  'KLM Sethamma': 2,
#  'Vijaya sekhara Naidu': 2,
#  'Nagabhushanam ': 2,
#  'Narayanamma': 2,
#  'P Ramesh Naik': 2,
#  'A V Ranga Rao': 2,
#  'P  Anuradha': 2,
#  'Mohanreddy': 2,
#  'Ansar Alam': 2,
#  'A Venkata Chalapathi': 2,
#  'Dr  M  Subbareddy': 2,
#  'T  Zeelani Basha': 2,
#  'G M  Venkatachalapathi': 2,
#  'G Ramudu': 2,
#  'P Nagabhushnam': 2,
#  'Sanathkumar Reddy': 2,
#  'Rufus Ronald': 2,
#  'T Alivelamma': 2,
#  'Sanjeevarayudu': 2,
#  'Hussainamma': 2,
#  'R Ravindra Kumar': 2,
#  'P Venkatachalapathi': 2,
#  'B S Srinivasulu': 2,
#  'Soujanya Lakshmi ': 2,
#  'Srinivasulu': 2,
#  'Kamala': 2,
#  'Anwesh Kumar': 2,
#  'Jayalaksmi': 2,
#  'gopinath': 2,
#  'R Ramesh Babu': 2,
#  'Nagendra Prasad': 2,
#  'P Nehemya': 5,
#  'Dr S Nagasuvarna': 2,
#  'S P Pullanna': 2,
#  'Sri T Zeelani Basha': 2,
#  'P Sree Devi': 2,
#  'Vara Prasad': 2,
#  'Mallikarjuna': 2,
#  'N Ramesh': 2,
#  'J.SREENIVASULU': 2,
#  'G Shubhakar': 2,
#  'B VIJAYALAKSHMI': 2,
#  'G Nagendra                ': 2,
#  'Adi Murthy': 2,
#  'M Uma Devi': 2,
#  'Satya Narayana': 2,
#  'Sailja': 2,
#  'Mondi Umadevi': 2,
#  'Anjaneyulu Nayak': 2,
#  'Siva Narayana Reddy': 2,
#  'P Nagabhushanam': 2,
#  'Radharamadevi': 2,
#  'V S Khadar Basha ': 2,
#  'Rajasekhar': 2,
#  'M Ravindra': 2,
#  'Fazlunnisabegum': 2,
#  'Harikrishna': 2,
#  'Damodar Reddy': 2,
#  'Y Nagaraju': 2,
#  'Hussainappa': 2,
#  'A Venkatachalapathi': 2,
#  'Dayakar': 2,
#  'H Eswarappa': 2,
#  'M Bhaskar Babu': 2,
#  'Vamsi Krishna': 2,
#  'S Nissar Ahhammad': 2,
#  'S Bharath Raj': 2,
#  'S Subbalakshmamma': 3,
#  'C Yerriswamy': 2,
#  'A Maddileti Swamy': 4,
#  'B Anil Kumar': 2,
#  'Venkataramana gowd ': 2,
#  'Shiva Kumar': 2,
#  'S Shakila Begum': 2,
#  'E Chalapathi': 2,
#  'Raghavendra': 2,
#  'J Nazeer Basha': 2,
#  'G Shankaraiah': 2,
#  'S Anil Kumar': 7,
#  'M Kaseppa': 2,
#  'V Vijay Kumar': 4,
#  'M Vijaya Lakshmi': 3,
#  'K Sankar Rao': 2,
#  'S Bhramaiah': 2,
#  'CM Chinna Narayanamma': 2,
#  'S YADAVENDRA': 2,
#  'M ANJINEYULU': 2,
#  'Y Sivavaral Reddy': 2,
#  'M SureshBabu': 2,
#  'CHANDRA SEKHAR ': 2,
#  'Hanumanthureddy': 2,
#  'B Sakunthala': 2,
#  'S Sivaiah': 2,
#  'M Muralidhar Naidu': 2,
#  'Sudhamani Kristam': 2,
#  'M Bala Kishan': 2,
#  'D Govindarajulu': 2,
#  'C Thirupal reddy': 2,
#  'Dinakar Babu Pulivandla': 2,
#  'Prudhvi Sagar Sathupati': 2,
#  'Y Nageswara Sastry': 2,
#  'M Suman ': 2,
#  'M Parvatappa': 2,
#  'V Ganganna ': 2,
#  'G Murali Krishna': 2,
#  'M AHAMAD BASHA': 2,
#  'V KONDAIAH': 2,
#  'D Umarani': 2,
#  'Dr B Venkat Reddy': 2,
#  'N Srinivasa Naik': 2,
#  'M Sannakka': 2,
#  'K Venkateswara Rao': 8,
#  'S Mahaboob Basha': 2,
#  ' M Madhu Kumar ': 2,
#  'H Obulapathi': 2,
#  'K Narasimha Rao': 2,
#  'D Sivakumar': 2,
#  'C V Varaprasad': 2,
#  'S Nagaraju': 2,
#  'G Adinarayana': 2,
#  'VIJAYA LAKSHMI BULLE': 4,
#  'RAJASEKHAR SANAPA': 2,
#  'NIRMAL KUMAR MIDDE': 2,
#  'SIVAIAH DASARI': 2,
#  'Khaseembee': 2,
#  'P D SREENIVASULU': 2,
#  'S Khuthijin khupra': 2,
#  'RATNASYAM RAY BANDARU': 2,
#  'THIMMAPPA UNDABANDA': 2,
#  'RAMESH S': 2,
#  'V V Sidda Reddy': 2,
#  'Bala Yellappa Jagga': 2,
#  'Noor Ahammad': 2,
#  'M Venkata Ramu': 2,
#  'Mahaboob Basha': 2,
#  'G V Chalamaiah': 2,
#  'Hari Prasad': 2,
#  'Yellappa': 2,
#  'Ranga Nethaji': 2,
#  'Naveen Kumar': 2,
#  'Kondaiah': 2,
#  'Bharathi': 2,
#  'Afjal Khan': 2,
#  'G Muneppa': 2,
#  'Guru Raja Prasad': 2,
#  'RAVINDRA JAGIRDAR': 2,
#  'PRABHAKAR DUNGAVATH': 2,
#  'SRAVAN KUMAR ADAVANI': 2,
#  'K SHEHANSHA': 2,
#  'VIJAYALAKSHMI': 2,
#  'P S S Dawood': 2,
#  'M Padma': 3,
#  'T Siva Reddy': 3,
#  'K Arunamma': 2,
#  'K Kumaraswamy': 2,
#  'P Kullai Swamy': 2,
#  'I Mamatha Devi': 2,
#  'N Praveenkumar': 2,
#  'K Ramakrishna': 4,
#  'D Mounika': 2,
#  'Guru Bramha': 2,
#  'M Krishna Naik': 2,
#  'N Baren Saheb': 2,
#  'R D Jagadhesh Babu': 2,
#  'J D Basavaraju': 2,
#  'Lakshmi Kanth': 2,
#  'U Devadas': 2,
#  'P Chendrayudu': 2,
#  'M K Rameshan': 2,
#  'P Nagaraju': 3,
#  'ADI NARAYANA SAKE': 2,
#  'NARASIMHULU PULA': 2,
#  'UDAY KUMAR ETELA': 2,
#  'RADHA KRISHNA HALLA': 2,
#  'K Raghurama Rao': 2,
#  'G Nagaraju': 4,
#  'Pradeep Krishna': 2,
#  'D Dastagiri': 2,
#  'Shirisha': 2,
#  'A Balarama Rao': 2,
#  'M Nagamani': 2,
#  'Vijaya Jyothu kumar ': 2,
#  'C Sreenivasulu': 2,
#  'B Prasad': 3,
#  'DILEEP KUMAR KURUBA': 2,
#  'V Sreedhar': 7,
#  'CHANDRAMMA ALUGU': 2,
#  'C Adinarayana Reddy': 2,
#  'C Sudhakar': 4,
#  'V Naganna': 4,
#  'VENKATA SUBRAMANYAM DOGUPARTHY': 2,
#  'M Krishna Mohan': 2,
#  'N Eswaramma': 2,
#  'P Diwakar': 2,
#  'R Katyayini': 2,
#  'NARASIMHA MURTHY-SUBRAMANYAMGARI': 2,
#  'JAGADEESH': 2,
#  'D VASANTHA LATHA': 2,
#  'GOPAL KURUBA': 2,
#  'G MANOHAR BABU': 2,
#  'N Narayana           ': 2,
#  'D Ramarao': 2,
#  'G Sathyanarayana': 2,
#  'P Usha Rani': 2,
#  'V Vijayalakshmi': 2,
#  'B Hanumanthu': 6,
#  'P Narendra Kumar': 2,
#  'K Maruthi Prasad': 2,
#  'Sreelatha': 2,
#  'S Shadab': 2,
#  'E Anandaiah': 2,
#  'A S Abdul Hameed Basha': 2,
#  'K Sreeramulu': 2,
#  'B Krishna': 2,
#  'P Praveenkumar': 2,
#  'S Khalimulla': 2,
#  'Lakshman Das': 2,
#  'V Giridhar': 2,
#  'Govardhana': 2,
#  'K Azad': 2,
#  'D Anjinappa': 2,
#  'IMRAN ATHAULLA': 2,
#  'M Sivaiah': 2,
#  'Mohandas': 2,
#  'P Chandrashekar Reddy': 2,
#  'V Thimappa': 2,
#  'H Sakunthala': 2,
#  'VISWANATH CHALLA': 2,
#  'SREE LAKSHMI KANDIBEDALA': 2,
#  'SIVANNA GOLLA': 2,
#  'CHANDANA KALASAMUDRAM C': 2,
#  'K Chennakrishna': 2,
#  'P Kesava Reddy': 2,
#  'P V Ramana': 2,
#  'M Adinarayana': 3,
#  'K Babu': 5,
#  'RAGHUNATHA GUPTHA NICHENAMETLA': 2,
#  'Smt D Swarnalatha': 2,
#  'B Nagamani ': 2,
#  'BHASKAR REDDY KAPADAM': 2,
#  'VASANTHA KUMAR PATRI': 2,
#  'R SURENDRA NAIK': 2,
#  'T ANAND KUMAR': 2,
#  'M SHAKUNTALA': 2,
#  'Harinatha Rao': 2,
#  'N G Chandrashekhar': 2,
#  'Shaikanna': 2,
#  'Rammohan': 2,
#  'Gopal': 2,
#  'N Sreenivasa Rao': 2,
#  'M H Suhasinamma': 2,
#  'Syamalamma': 2,
#  'K Lakshmi Narasimhulu': 2,
#  'Bellur Prabhakar  ': 2,
#  'P Boyez babu': 2,
#  'B Ramanjinamma': 2,
#  'B Sudhakar naik': 2,
#  'K R Lalithamma': 2,
#  'M Rajasekhar': 4,
#  'G Prasanna Kumar': 2,
#  'N Rajasekhar': 2,
#  'R Madhavareddy': 2,
#  'K M Ranganna': 2,
#  'S MAQBUL BASHA': 2,
#  'K DIVAKAR': 2,
#  'M THIRUPAL NAIK': 2,
#  'S Sreenivasulu': 4,
#  'K Vemanarayana': 2,
#  'B Babu Rao': 2,
#  'Kamala Bai': 2,
#  'Gopal Naik': 2,
#  'S Rama suresh babu ': 2,
#  'T Yoganadha Reddy': 2,
#  'M Gudenna': 2,
#  'L Reddy': 2,
#  'G Nataraj': 2,
#  'S Lalithamma': 2,
#  'P Reddappa': 2,
#  'K Nagaraju': 2,
#  'Vijaya Lakshmi': 3,
#  'T Nagaraja Rao ': 2,
#  'M Bharat Kumar': 2,
#  'Chaitanya': 2,
#  'Radhika': 3,
#  'Lakshmidevamma': 2,
#  'N Sivasankarappa': 2,
#  'R Rakesh Naik': 2,
#  'B Sreeramulu': 3,
#  'G Krishnaiah': 2,
#  'SAI LAKSHMI KURUBA': 2,
#  'VENKATA RAMANA NAIK THANDA': 2,
#  'K Prakash Rao': 2,
#  'K Suryanarayana': 3,
#  'SATYANARAYANA C': 2,
#  'D M Subhan': 2,
#  'ASHOK KUMAR REDDY NAGIREDDY GARI': 2,
#  'M G Lakshminarayana': 2,
#  'Golla Narasimhamurthy': 2,
#  'Jamsheer Basha ': 2,
#  'B RamaKrishana': 2,
#  'B Jayachandra Reddy': 2,
#  'G Rama sekhar': 2,
#  'N Chandra Sekhar': 2,
#  'Ibrahim Saheb': 2,
#  'S Elizabeth': 2,
#  'B Anjineyulu Naik': 2,
#  'Vishnuvardhan Reddy': 2,
#  'Venkateswara Rao Kallur Srinivas Rao': 2,
#  'N Jayaram': 2,
#  'M venkatalakshmma': 2,
#  'Venkataramana': 2,
#  'G Eswaramma': 2,
#  'T Ramakarishna': 2,
#  'M Subbarayudu': 2,
#  'A Venkataramaudu': 2,
#  'B Venkataramireddy': 2,
#  'G Sumathi': 2,
#  'B V Sivaiah    ': 2,
#  'M Narasimhareddy': 2,
#  'M ADINARAYANA': 2,
#  'HARINATH REDDY': 2,
#  'V RAMESH BABU': 2,
#  'M Chandrasekhar': 2,
#  'K SAKUNTHALA': 8,
#  'K DAYANANDAM': 8,
#  'P NAGESWARAO': 4,
#  'A GOPALAIAH': 8,
#  'D AJAY KUMAR': 5,
#  'Dr K SATHEESH KUMAR': 7,
#  'R Sreenivasan': 8,
#  'M SRIKANTH REDDY': 3,
#  'A SELVARAJ': 2,
#  'V CHANDRA SEKHAR': 4,
#  'G VEMA SULOCHANA': 3,
#  'G Ravindra Reddy': 7,
#  'B MADHAVI LATHA': 2,
#  'J BINDU PRIYA': 4,
#  'P RAJENDRA PRASAD (FAC)': 2,
#  'A SHYLA': 7,
#  'K VENKATASRINIVAS': 3,
#  'P RAJENDRA PRASAD': 4,
#  'K KALPANA': 2,
#  'B RAMA NAIK': 4,
#  'K Bennuraj': 6,
#  'O Sivaraj': 6,
#  'Dr P Parthiban': 3,
#  'M Srikanth Reddy': 3,
#  'S MALLIKARJUNA': 5,
#  'M Prasad Babu': 4,
#  'K Sudhakar': 6,
#  'G Rajasekhar': 9,
#  'S Ravi Kumar': 3,
#  'D MUTHYALU': 5,
#  'M Venkatarathnamma': 5,
#  'M VENKATARATHNAMMA FAC': 4,
#  'Shaik Jareena': 4,
#  'M VIJAYA KUMAR': 11,
#  'D Rajesh ': 2,
#  'R Priyanka': 3,
#  'P N Sreedevi': 2,
#  'K Venkataramana': 3,
#  'D Suseeladevi': 5,
#  'M Dhanalakshmi': 10,
#  'R Gopala krishnaiah': 3,
#  'B Srinivasulu': 5,
#  'M Keerthi': 4,
#  'B GANGABHAVANI': 5,
#  'A Vijayakumar': 2,
#  'G Yamini': 3,
#  'M Balakrishnaiah': 8,
#  'K NARAYANA': 4,
#  'K V MOHAN VARMA': 5,
#  'P Sreenath': 2,
#  'P RUKMINAMMA': 4,
#  'T G Mohanavalli': 3,
#  'C Sunilkumareddy ': 2,
#  'G Ravi': 5,
#  'A KIRANMAYI': 3,
#  'B Sasirekha': 6,
#  'K MURALI MOHAN': 2,
#  'S PARVATHAMMA': 6,
#  'P PREMALATHA': 2,
#  'P KRISHNA REDDY': 3,
#  'Dr V SREEHARI': 5,
#  'M PRASAD BABU': 5,
#  'P Krishna kishore': 4,
#  'B SRIDEVI': 7,
#  'K Siva Prasad': 3,
#  'P Srinivasulu': 8,
#  'G K NIRMALA DEVI': 4,
#  'G C Venkateswarlu': 3,
#  'M Lokeswari': 4,
#  'Kavitha': 3,
#  'C Ravindranath Tagor': 5,
#  'K VENKATESWARLU': 10,
#  'K MERY PREMALATHA': 3,
#  'K UMA VANI': 5,
#  'R MADHURI': 4,
#  'R VENKATALAKSHMAMMA': 4,
#  'ARUNACHALA REDDY SOLINGAPURAM': 4,
#  'K DASTAGIRI': 3,
#  'P Sunilkumar Reddy': 3,
#  'K Ramani': 6,
#  'G RAVI KUMAR': 8,
#  'A Divya': 6,
#  'R J Umasankari': 5,
#  'K SANKARAIAH': 7,
#  'S Shobarani': 4,
#  'N M Gurappa': 4,
#  'B SRILAKSHMI': 6,
#  'S PADMAVATHI': 4,
#  'Vijaya Mohan': 2,
#  'G Chinnaiah': 5,
#  'K Maheswara Reddy': 6,
#  'K Hemakumar ': 3,
#  'C Vijayabhaskar': 3,
#  'A RAJASEKHAR REDDY': 5,
#  'P Surendranath': 5,
#  'K BALAGANESH': 4,
#  'V Janakamma': 3,
#  'T ANJANEYULU': 3,
#  'A Thukaram': 3,
#  'P Pushpavathi': 4,
#  'K JAYAPRAKASH': 5,
#  'P Vani': 5,
#  'R Amaranadh': 3,
#  'B Reddappa': 3,
#  'G GIRIDHAR REDDY': 5,
#  'M Hariprasad Reddy': 5,
#  'G DHANALAKSHMI': 5,
#  'G DAMODAR REDDY': 3,
#  'M Balaramudu': 3,
#  'L V RAJA GOPAL RAO': 6,
#  'J V SANKAR': 7,
#  'N VASUDEVAN': 3,
#  'K L SAILEELA': 2,
#  'NR Hemalatha': 3,
#  'D Venkata Rathnam': 3,
#  'C Sanjeevi Reddy': 3,
#  'P Ramanaiah': 5,
#  'Y Satyanarayana': 3,
#  'JANNAM BHGYALATHA': 3,
#  'KONDREDDIGARI KESAVA REDDY': 4,
#  'DAMA VIDYASAGAR': 4,
#  'MANGALAM SANKARAIAH': 6,
#  'G MOHAN KUMAR': 2,
#  'M Vidyarama': 6,
#  'N Jayachandra': 3,
#  'A Geetha Kumari': 5,
#  'T Santha Kumari': 2,
#  'B BABU RAO': 5,
#  'K SREEDEVI': 2,
#  'M MUNIKRISHNA': 2,
#  'S AKBAR HUSSAIN': 4,
#  'I V RAMANA': 5,
#  'C Srinivasulu': 3,
#  'Y Divakara reddy': 5,
#  'P Surendra babu': 3,
#  'P Viswesara reddy': 3,
#  'A SULOCHANA': 2,
#  'K RAJENDRA PRASAD': 4,
#  'CH Narayana': 3,
#  'S ABDUL KALAM AZAD': 2,
#  'B Venkatramana': 3,
#  'S NATARAJA': 3,
#  'B Indiramma': 2,
#  'M Hemalatha ': 4,
#  'A Murali': 4,
#  'N Latheef Khan': 3,
#  'K Ramchandra': 5,
#  'U Sravani': 3,
#  'P Reddy Basha': 3,
#  'Dr M S Ravi Shankar': 3,
#  'A S Nazeer Ahmed': 5,
#  'P Venkataramana': 13,
#  'S Mahaboob basha': 10,
#  'R Dilip Kumar Naik': 2,
#  'C Gangaiah': 2,
#  'D Savithri': 2,
#  'T Lakshmi': 2,
#  'U Rangaswamy': 4,
#  'C Leela Madhavi': 2,
#  'K Prabhakara Reddy': 2,
#  'V Lakshmipathi': 2,
#  'Dr K N V Prasad Reddy': 2,
#  'SHAIK TAJ MASROOR': 5,
#  'M V RANAMA KUMAR': 3,
#  'SHAIK ABDUL SHUKUR': 3,
#  'G Venkatasubbaiah': 3,
#  'M Venkatarathanam': 4,
#  'S Maheswari Bai': 2,
#  'B S Venu Gopal': 2,
#  'A S Giridhar': 4,
#  'S Hurmath': 2,
#  'J Sreenivas': 2,
#  'P DHANAMJAYA': 7,
#  'P HEMALATHA': 5,
#  'N SREENIVASULU': 8,
#  'M SURENDRA': 5,
#  'B Kishor Naick': 3,
#  'A Sridhar Rao': 5,
#  'S Subhadra': 3,
#  'M Jagan Mohan Reddy': 2,
#  'P Manohar': 2,
#  'K Padmarani': 6,
#  'R Vikram Reddy': 2,
#  'N Narayana': 2,
#  'K Naveen Kumar': 2,
#  'DS Abdul Munaff': 4,
#  'K Devendra Babu': 3,
#  'A Vasundhara': 4,
#  'C V Karunakar Reddy': 3,
#  'V Jyothamma': 3,
#  'K Pavan Kumar': 2,
#  'JLR Varaprasad ': 4,
#  'NR Lakshmipathynaidu ': 6,
#  'S Madhava Raju': 3,
#  'P Leelarani': 4,
#  'A Sivaprasad': 6,
#  'Dhanaraj': 2,
#  'U Chinnareddaiah': 6,
#  'Kadhar Sharif': 3,
#  'V VENKATASIDDAIAH': 6,
#  'Y SUDHAKAR': 2,
#  'P CHALAPATHI RAO': 5,
#  'C HEMALATHA': 2,
#  'B RAMACHANDRAIAH': 2,
#  'V B MALATHY': 3,
#  'T SURYAPRAKASH REDDY': 3,
#  'A G UMALAKSHMI': 3,
#  'M L N S PRASAD': 4,
#  'G APPOJI': 5,
#  'G LAKSHMIDEVI': 5,
#  'I SATHYANARAYANA RAO': 5,
#  'CHANDRA SEKHAR KALIKIRI': 4,
#  'J MADHAVI': 3,
#  'K MUNICHANDRA REDDY': 2,
#  'B SREERAMULU': 3,
#  'T THYAGARAJAN': 5,
#  'M HANUMAN NAIK ': 3,
#  'N RAMACHANDRA': 5,
#  'Y UDAYA BHARATHI': 3,
#  'SHAIK ABDUL GAFOOR': 4,
#  'M BALAJI NAIK': 2,
#  'S SUJANA SREE': 2,
#  'V SURESH BABU': 3,
#  'B THYAGARAJU': 4,
#  'B RAMAKRISHNA': 4,
#  'D LEELA KUMARI': 3,
#  'A SREEDHAR RAO': 3,
#  'P SURENDRA BABU': 3,
#  'SHAIK SHABEER AHAMAD': 5,
#  'A KALAVATHI': 5,
#  'U MURALI MOHAN': 2,
#  'K N BALAJI': 5,
#  'GUNAGANI ASWANI': 3,
#  'M S CHANDRASEKHAR': 4,
#  'S AMRUTHAVALLI': 3,
#  'K SUBRAMANYAM': 3,
#  'P VENKATA SUBRAMANYAM': 4,
#  'T MURALI MOHAN REDDY': 3,
#  'P SIRISHA': 2,
#  'Dr BHASKAR': 3,
#  'A V SUBBARAO': 2,
#  'M NARASIMHAMURTHY': 4,
#  'K RAVINDRANATH': 3,
#  'B VIJAYSIMHAREDDY': 5,
#  'G VIJAYAKUMARI': 4,
#  'DR C ARUNKUMAR': 6,
#  'B Sankaralal naik': 5,
#  'Dr B Muneiah': 5,
#  'Venkatarayulu': 6,
#  'Dr G Venkatanarayana': 8,
#  'D N Sailaja': 4,
#  'Dr V Sathessh': 5,
#  'N Manjula': 6,
#  'P Sitharamaiah': 5,
#  'K Chittibabu': 4,
#  'K Prakash Babu': 5,
#  'T Lakshmipathi': 4,
#  'A  BABAIAH': 5,
#  'V SREENIVASULU': 4,
#  'T  LAKSHMIPATHI': 3,
#  'S KHALEEL SAHEB': 4,
#  'K KALAVATHI': 3,
#  'K Babu Rajendra Prasad': 6,
#  'A AMARNADH': 6,
#  'T Shanmugham': 5,
#  'B SURESH NAIDU': 3,
#  'B Haritha Kumari': 5,
#  'Chittor Dhanamjaya': 3,
#  'K BABJI': 2,
#  'G Sreedevi': 11,
#  'Korivi Hemamalini': 3,
#  'Sappani Kodandaiah': 3,
#  'M Kiran Kumar': 4,
#  'N Hariprasad': 5,
#  'D Krishnaiah': 5,
#  'J Chaithanya Sravanthi': 4,
#  'C Siddaramaiah': 4,
#  'B Rajeswary': 3,
#  'B Sugunamma': 4,
#  'D SAILAJA KUMARI': 3,
#  'V ARUNA': 4,
#  'K Sudhakar Rao': 5,
#  'G INDIRA DEVI': 3,
#  'Dr G Suman Kumar': 2,
#  'M NARSIMHULU NAIDU': 2,
#  'R GLOWRI': 3,
#  'NARAIAH': 5,
#  'K RAVI': 5,
#  'P C SREENIVASULU': 7,
#  'P SURENDRANADH': 8,
#  'I Subramanyam': 8,
#  'R Bhuvaneswari': 8,
#  'E RameshReddy': 8,
#  'MVN Rajendra': 8,
#  'SA Mahammad Raffe': 8,
#  'M Varalakshmi': 4,
#  'N Silpa Reddy': 2,
#  'CH BHARATHI MANJU': 5,
#  'T UGANDHAR': 5,
#  'T ARUNAMMA': 5,
#  'D VENKATA BHAGYALAKSHMI': 5,
#  'S MANI': 5,
#  'PV VEERABADRA REDDY': 2,
#  'V RAVI KUMAR NAIDU': 9,
#  'P RAJAGOPAL': 5,
#  'B MAMATHA': 5,
#  'P MANOHAR': 3,
#  'M RUPENDRA NADH REDDY': 5,
#  'G Saraswathi': 4,
#  'D Uma': 5,
#  'S Venkateswarlu': 5,
#  'G Srinivasarao': 8,
#  'Dr B Pareeshkumar': 2,
#  'K Subramanyam': 6,
#  'TUPAKULA CHINNA REDDAPPA': 6,
#  'C V SUBBANNA': 6,
#  'K SUHARLATHA': 6,
#  'I MURALI': 6,
#  'Dudyala Neela Kanteswar Reedy': 10,
#  'D Premalatha': 6,
#  'J.V.Kanaka Durga': 2,
#  'V Suswagatham': 2,
#  'B Gowtham Kumar': 3,
#  'P.B.S.Amarnath': 2,
#  'M.Krishna Kumar': 2,
#  'Dr. N Revanth Kumar': 2,
#  'Dr M Praveen Kumar Varma': 2,
#  'C H Subrahmanyam': 2,
#  'Dr G Sahitya Bhukta': 2,
#  'G.Kumarbabu': 2,
#  'Smt V.Santhamani': 3,
#  'Sri D Prasad Raju': 2,
#  'S V V Satyanarayana': 2,
#  'Sri J.Sri Rama Ravi Kiran': 2,
#  'Sri V.Ratnam': 2,
#  'Sri V.David Raju': 2,
#  'Sri K.Dharma Prasad': 2,
#  'Smt V.Satyavathi': 2,
#  'Ch Sriram': 2,
#  'B CHALAMAYYA': 2,
#  'G.Sivarama krishnayya': 2,
#  'A Shara Rani': 2,
#  'N V V Satyanarayana': 2,
#  'B Baby Janambha': 2,
#  'V Anuradha': 2,
#  'K A S S SrinivasaRao': 2,
#  'E Dhanaraj': 2,
#  'D Vimala Kumari': 2,
#  'P SARADA': 2,
#  'ABVSB Srinivas': 2,
#  'B Manga Devi': 2,
#  'D Srinivas': 2,
#  'Tuthika Srinivasa Viswanadh': 2,
#  'M Subhash Babu': 2,
#  'K Rajasekhar': 3,
#  'KSS Malleswara Rao': 2,
#  'D Y Narayana': 2,
#  'J A Jhansy': 2,
#  'P Ramoji': 2,
#  'Sri K.Ch.Apparao': 3,
#  'Sri.N.Venkateswara rao': 3,
#  'Smt. M. Satya Devi': 2,
#  'Smt.K.Padmajyothi': 3,
#  'Sri.M.Vidya Sagar': 3,
#  'N.Ramesh': 3,
#  'K.Venkateswara Rao': 3,
#  'S.S.Sarma': 3,
#  'Ch.V.V.Satya Prasad': 3,
#  'B Sri Vidya': 3,
#  'Smt M.Vijaya Sri': 2,
#  'Smt Ch. Ramya Priyanka': 3,
#  'D. Venkateswararao': 2,
#  'P. Poorna Chand': 2,
#  'I. Vimala': 2,
#  'Sri PVVSAV Prasad': 3,
#  'M. Sai Bhaskar': 2,
#  'Sri S. Srinivasa Rao': 2,
#  'S SIVARAM': 2,
#  'Y Rambabu': 3,
#  'P Srinivasa Rao': 7,
#  'S P V USHA RANI': 2,
#  'G CHINABABU': 3,
#  'Sri Y S Prakashrao': 3,
#  'Sri B.Ramana Sri': 2,
#  'Sri D.Rambabu': 2,
#  'V Srinivasa Rao': 7,
#  'Y Madhukumar': 2,
#  'Sri V V R Subrahmanyam': 2,
#  'Sri D.Sunil Kumar': 4,
#  'J Srinivas': 3,
#  'D Srilakshmi': 3,
#  'Sri CH.D.Vijay Kumar ': 3,
#  'Smt K.Heleena': 3,
#  'Sri M.Prabhakararao': 4,
#  'K Venkateswararao': 5,
#  'G Rajendra Prasad': 2,
#  'P Nagamani': 5,
#  'N V SOMAYAJULU': 2,
#  'J N S GOPALAKRISHNA': 2,
#  'V BABJIRAJU': 3,
#  'S SANJEEVA RAO': 2,
#  'G LAKSHMIPATHI': 2,
#  'K RAMAMOHAN': 2,
#  'CH RAMAKRISHNA': 2,
#  'CH TRISULAPANI': 3,
#  'P V SATYANARAYANA RAJU': 2,
#  'G KRISHNA': 2,
#  'S RAKESH': 2,
#  'M RAJARAJESWARI TALLLI': 2,
#  'P.Chakradhara Rao': 2,
#  'K.S.Gowri Kumari': 2,
#  'M V V S NarayanaRao': 2,
#  'Y.Sobha': 2,
#  'CH CHINA VENKATA RAO': 2,
#  'P Lakshmipathiraju': 2,
#  'J V Satyanarayana': 2,
#  'P VIJAYA THAMAS': 2,
#  'K APPARAO': 2,
#  'Y JAYA': 2,
#  'DASARI VENKATA RAMANA': 6,
#  'K BULLIKRISHNA VENI': 4,
#  'CH V NARASARAO': 4,
#  'E. SATISH KUMAR': 4,
#  'V MURALIDHAR': 5,
#  'S POTHURAJU': 3,
#  'K BULLIKRISHNAVENI': 2,
#  'K.Subrahmanyam': 2,
#  'K.V.V.Chowdary': 2,
#  ' P V Seetha Pathi Rao': 2,
#  'T.V. Suresh': 2,
#  ' B suresh kumar': 2,
#  'Smt. S Subhashini': 3,
#  'PEPAKAYALA MANESWARA RAO': 2,
#  'A ATCHYUTA RAO': 2,
#  'B SIVAPRASAD': 2,
#  'NORI KAMASASATRY': 3,
#  'CH BALAJI VENKATA RAMAN': 4,
#  'S RUPAKALA': 3,
#  'M.VENKATESWARARAO': 2,
#  'K.HARI KRISHANA SATYA REDDY': 2,
#  'CH.SATYANARAYANA ': 2,
#  'V.S.V.V.K,V.R.MURARJI': 2,
#  'T.S.S.R.K.MARUTHIRAO': 2,
#  'P.A.S.E.C.V.S.KUMAR': 3,
#  'RV PRASAD': 3,
#  'KSS SUBBARAO': 3,
#  'Yinti Gangadhar': 3,
#  'B Subhashini': 2,
#  'Janga Jessy florance': 2,
#  'PV Ramanuja Rao': 3,
#  'B.SUGUNA': 2,
#  'M Somireddy': 2,
#  'Y.S. Haranadharao ': 2,
#  'T.D.R.Padmavathi': 2,
#  'N.Samuel John': 2,
#  'I Venkata Rao': 3,
#  'P.Manoj Kumar': 2,
#  'Smt A.Siri': 3,
#  'Sri L.Joseph': 2,
#  'Sri Ch.Chinababu': 3,
#  'Smt A.Mangayamma': 3,
#  'Sri V.Nagababu': 3,
#  'Sri J.Venkateswara Rao': 2,
#  'G.Bhavani': 2,
#  'K.V.V.SATYANARAYANA': 2,
#  'G.Srinivasa Rao': 6,
#  'P.Narayanamurthy': 6,
#  'Smt.K.Geetanjali': 3,
#  'Sri.K.Ramesh ': 3,
#  'Sri.K.Hunya Naik': 2,
#  'K.Viswanath': 2,
#  'Sri.P.Srinivas': 2,
#  'Sri.D.Suryakumar': 2,
#  'Sri P V Narayana': 3,
#  'R.Swamy': 2,
#  'Ch.Vinod Kumar': 2,
#  'Ch.Srinivasarao': 3,
#  'K.V.Suryanarayana': 4,
#  'Ch Srinivasarao': 3,
#  'K.Srinivasarao': 3,
#  'Ch satyanarayana ': 2,
#  'smt D.SriLalitha ': 3,
#  'R NAGESWRARAO': 2,
#  'P K V Lakshmi': 2,
#  'BVS ramacharyulu ': 2,
#  'S. Madhusudhan.': 3,
#  'V. Ravi Shankara Rao': 4,
#  'A. Venkata Satya Srinivas. ': 3,
#  'P.Sri Pallavi.': 2,
#  'M Vani': 2,
#  'K.Tataiah': 2,
#  'K.S.S.N.Raghupathi': 2,
#  'P.Vasantha Madhavi  ': 2,
#  'T.Gayatri': 2,
#  'K.Dwaraka Devi': 2,
#  'V.Padmaja ': 2,
#  'K.Himamaheswari  ': 2,
#  'G.Balasubrahmanyam ': 2,
#  'A.Vijaya Lakshmi': 2,
#  'V.Raja Babu': 4,
#  'K.Nagamalleswara Rao': 4,
#  'A.V.Rajesh': 4,
#  'N.Venkateaswarao': 3,
#  'M.Anupama': 5,
#  'Smt.A.Gowri Devi': 2,
#  'Sri.K.Srinivasarao': 2,
#  'Sri.K.Kishor Kumar': 2,
#  'Smt.M Bharathi': 2,
#  'AA.ABBAS': 4,
#  'P.GANDHI': 3,
#  'PVV Sathyanarayana': 3,
#  'M.SRINU': 3,
#  'G.Kishore': 4,
#  'S.V.NAIDU': 3,
#  'Sri R.L.N.Setty': 2,
#  'Sri K.J.Chandrasekhar': 3,
#  'Sri S.Venkataramana': 2,
#  'Sri M.Srinu': 2,
#  'I N V Suresh Kumar ': 2,
#  'B.Mamatha': 3,
#  'S.Apparao': 3,
#  'M BRAHMA PRASAD': 2,
#  'S V SURYANARAYANA ': 2,
#  'Sheik Babji ': 2,
#  'B Appalaraju': 2,
#  'M.Someswara Reddy': 2,
#  'L Narayanarao': 2,
#  'Dandu Arunu Kumar': 2,
#  'Bandari suryanarayana': 3,
#  'Karri bheemeswar': 3,
#  'Sri.B.ABBAI': 2,
#  'Sri.M.Ravindrakumar': 2,
#  'Sri.P.R.C.Rajkumar': 2,
#  'Sri.V.ASHOK': 2,
#  'Kum.K.Divyasri': 2,
#  'Smt.M.ANUPAMA': 2,
#  'P V S R Krishna Murthy': 2,
#  'Ch Mounika': 2,
#  'SMT.K.PADMAVATHI': 2,
#  'SRI. K.V.N.RAMESH KUMAR': 2,
#  'M Suresh Kumar': 3,
#  'P.Srilakshmi': 3,
#  'T.Nandana': 2,
#  'B.Ashok Kumar': 2,
#  'D.S.Sarma': 2,
#  'M.Rajeswararao': 2,
#  'N.Bijji': 2,
#  'P.Gopala Krishna': 2,
#  'B.Gowramma': 2,
#  'G. Bhima Rao': 6,
#  'Md. Yarkhan': 5,
#  'N. Satya Prasad': 5,
#  'M. Krishnarjuna': 5,
#  'DVLN. Sastry': 5,
#  'K.RAJYA LAKSHMI': 2,
#  'K.RATNA KUMARI': 3,
#  'Y.V.V.N.S LAKSHMI': 2,
#  'B. Sai Satyanarayana': 3,
#  'V.Abraham Lincoln': 3,
#  'P.Suresh': 2,
#  'K.Tata Rao': 3,
#  'K.V.S Mohan Krishna': 3,
#  'T Kusalava Dora': 3,
#  'P.R.K Bhagavanulu': 3,
#  'D.Srinivasa Rao': 4,
#  'Riyaz Hussain': 2,
#  'M Raja Babu': 2,
#  'G Ramesh': 8,
#  'K.Sita Ramalakshmi': 2,
#  'B.Ravi': 2,
#  'G SATYANARAYANA': 2,
#  'K.V.V.Satyanarayana': 2,
#  'Sri Cm.Sai Kanth Varma': 4,
#  'Sri K. Posibabu': 2,
#  'Sri A.Ramanareddy': 3,
#  'Sri E. Maheswararao': 5,
#  'J Jhansi Rani ': 4,
#  'Y Suseela Kumari': 2,
#  'Sri Vollu Apparao': 2,
#  'K Surya Ramesh': 2,
#  'M Satyanarayana Murthy ': 2,
#  'N John Milton': 2,
#  'P.V.V. SATYANARAYANA': 5,
#  'T.V.R.MANIDEEP': 5,
#  'M.RAMAKRISHNAREDDI ': 6,
#  'M.SRINIVAS ': 4,
#  'A.NAGA SRAVANI': 4,
#  'Smt M Bindu': 2,
#  'P.Mukteswararao': 2,
#  'V.sita': 2,
#  'Sri D.Srinivasa Rao': 3,
#  'Sri Ch.Ramarao': 2,
#  'Sri V.Avinash': 3,
#  'Sri G Nagendra Vara Prasad': 2,
#  'Sri K.Swamy Naik': 2,
#  'V.MURALI KRISHNA': 3,
#  'U.M.S.NAGESWARA RAO': 3,
#  'K.BAPANNA DORA': 4,
#  'M.RENUKA CHANDINI': 2,
#  'Dr.P.Chandrasekhar': 2,
#  'N.Daivakumar': 2,
#  'V.JHANSI RANI': 2,
#  'T.Giri Prasad Varma': 2,
#  'Sri. P. Tejeswara Rao': 5,
#  'Sri. P. Venkata Ratnam': 6,
#  'Sri. K. Sanjeev Kumar': 4,
#  'D Sattibabu': 2,
#  'V.V.J.Laxmi Bai': 3,
#  'S.Srinivasu': 3,
#  'S.Satyanarayana': 2,
#  'K.Praveen': 3,
#  'Smt  S G Sarala': 2,
#  'V S R KRISHNA': 2,
#  ...}

# %% [markdown]
# ### Mobile Number
# <a class="anchor" id="4.6"></a>
# Mobile Number

# %% [markdown]
# ### Address for Communication
# <a class="anchor" id="4.7"></a>
# Communication Address
