# %%
import pandas as pd
import csv
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
givingTuesday = pd.read_csv("C:\\Users\\shaya\\Desktop\\DaanMatch\\Final_Data_givingtuesdayindia.org.csv", encoding='cp1252')
givingTuesday.head(5)
# Out:
#                                                  Url  \
# 0  https://www.givingtuesdayindia.org/ngo-detail/...
# 1  https://www.givingtuesdayindia.org/ngo-detail/...
# 2  https://www.givingtuesdayindia.org/ngo-detail/...
# 3  https://www.givingtuesdayindia.org/ngo-detail/...
# 4  https://www.givingtuesdayindia.org/ngo-detail/...
#
#                                             NGO Name  \
# 0  `Sahaj' (An Organisation for Women's Development)
# 1  "DIVYA RASA" (Centre for Healing, Learning, Re...
# 2                      "Sankalp" Manav Vikas Sanstha
# 3  "VISHA" VOCATIONAL INSTITUTES SOCIAL,HEALTH AN...
# 4                                17000 ft Foundation
#
#                   Popular Name  Year of Establishment  \
# 0                        Sahaj                 2001.0
# 1  Divya Rasa - Temple of Love                 2015.0
# 2                          NaN                 1992.0
# 3                    VISHA NGO                 2012.0
# ...

# %%
givingTuesday.drop(givingTuesday.columns[23:29], axis=1, inplace=True)

# %%
givingTuesday['Annual Expenditure (Rs in lacs)'].unique()
# Out:
# array([nan, '518 lakhs', '18000000', '4,21,671/-', '1970676.66', '434274',
#        '549791.97', '8500000', '3000000', '9205922', '38.53', '52.98',
#        'Rs. 452272.20/-', 'seventy Lakh', '4569409', '84.86', '464958',
#        '44272000', '2574229', '8', '5000000',
#        'One Crore Thirty Three Lakhs', '4025652.8', '6022233', '132472.8',
#        '4472700', '2,624,633.00', '2675904', '2959117', '4300000',
#        '74,356,470.91', '383.65', '600000', '150 LACS', '11.79',
#        '13052392.84', '15000000', '5', '1810767', '25 lakhs', '300,000',
#        '2,048,044', '4,187,879', 'below 5 lakh', '2,600,000.00',
#        '4507217.87', '3776029', '10.28865', '180670360', '361000',
#        '3467049', '2847876', '1354000', '37549665', '51871292.35',
#        '300000', '25,00,435/-', '11.38977', '585,118.50', '1960.93',
#        '1279.22', '523.71', '1098.62', '195.61', '1810.34', '4285.12',
#        '848.7', '1344.03', '220.75', '184.12', '243.33', '670.74',
# ...

# %%
givingTuesday.dtypes
# Out:
# Url                                 object
# NGO Name                            object
# Popular Name                        object
# Year of Establishment              float64
# GuideStar URL                       object
# Full Time Staff                     object
# Full Time Volunteers               float64
# Brief description                   object
# Annual Expenditure (Rs in lacs)     object
# Year for Annual Expenditure         object
# Impact                              object
# Profile pic                         object
# Organisation Website                object
# Email                               object
# Telephone/ Mobile number            object
# Correspondence  Address             object
# Phone                               object
# Cause(s)                            object
# Nature of Intervention              object
# Beneficairies                       object
# Focus                               object
# Area of Operation: State            object
# ...

# %%
##givingTuesday['Year of Establishment'] = givingTuesday['Year of Establishment'].astype(int)
non_numeric = pd.to_numeric(givingTuesday['Year of Establishment'], errors='coerce').isna().any()
print(non_numeric)
print(givingTuesday['Year of Establishment'].unique())
# Out:
# True
# [  2001.   2015.   1992.   2012.   2000.   1999.   2005.   2006.   2002.
#    2009.   2008.   2007.   2014.   1993.   1991.   2013.   1979.   1969.
#    2004.   1989.   1997.   1978.   2017.   1995.   1990.   1977.   2016.
#    2010.   1972.   1988.   1998.   1996.   1980.   2011.   1983.   1985.
#    1994.   1937.   1987.   2018.   1976.   1986.   1959.   2003.   1981.
#    1982.   1963.   1922.   1968.   1975.   1971.   1984.   1961.   1974.
#    1956.   1954.   1949.   1967. 431731.   1953.   1964.   1940.   1966.
#      nan]

# %%
invalid_row = givingTuesday[givingTuesday['Year of Establishment'] == 431731]
invalid_row
# Out:
#                                                    Url  \
# 592  https://www.givingtuesdayindia.org/ngo-detail/...
#
#                         NGO Name                 Popular Name  \
# 592  Sanskriti Samvardhan Mandal  Sanskruti Samvardhan Mandal
#
#      Year of Establishment                                      GuideStar URL  \
# 592               431731.0  https://guidestarindia.org/Summary.aspx?CCReg=...
#
#     Full Time Staff  Full Time Volunteers  \
# 592             250                   5.0
#
#                                      Brief description  \
# 592  Sanskriti Samvardhan Mandal is a village based...
#
#     Annual Expenditure (Rs in lacs) Year for Annual Expenditure  ...  \
# 592                       180670360                  FY 2018-19  ...
#
#                   Email Telephone/ Mobile number  \
# 592  admin@ssmandal.net                      NaN
#
#                                Correspondence  Address Phone  \
# ...

# %%
givingTuesday['Year of Establishment'].replace(431731.0, np.nan, inplace=True)

row_593 = givingTuesday.iloc[592]
print(row_593)
# Out:
# Url                                https://www.givingtuesdayindia.org/ngo-detail/...
# NGO Name                                                 Sanskriti Samvardhan Mandal
# Popular Name                                             Sanskruti Samvardhan Mandal
# Year of Establishment                                                            NaN
# GuideStar URL                      https://guidestarindia.org/Summary.aspx?CCReg=...
# Full Time Staff                                                                  250
# Full Time Volunteers                                                             5.0
# Brief description                  Sanskriti Samvardhan Mandal is a village based...
# Annual Expenditure (Rs in lacs)                                            180670360
# Year for Annual Expenditure                                               FY 2018-19
# Impact                             SSM says it runs one of the largest residentia...
# ...

# %%
givingTuesday['Year of Establishment'] = givingTuesday['Year of Establishment'].astype('Int64')

# %%
givingTuesday['Annual Expenditure (Rs in lacs)'].unique()
# Out:
# array([nan, '518 lakhs', '18000000', '4,21,671/-', '1970676.66', '434274',
#        '549791.97', '8500000', '3000000', '9205922', '38.53', '52.98',
#        'Rs. 452272.20/-', 'seventy Lakh', '4569409', '84.86', '464958',
#        '44272000', '2574229', '8', '5000000',
#        'One Crore Thirty Three Lakhs', '4025652.8', '6022233', '132472.8',
#        '4472700', '2,624,633.00', '2675904', '2959117', '4300000',
#        '74,356,470.91', '383.65', '600000', '150 LACS', '11.79',
#        '13052392.84', '15000000', '5', '1810767', '25 lakhs', '300,000',
#        '2,048,044', '4,187,879', 'below 5 lakh', '2,600,000.00',
#        '4507217.87', '3776029', '10.28865', '180670360', '361000',
#        '3467049', '2847876', '1354000', '37549665', '51871292.35',
#        '300000', '25,00,435/-', '11.38977', '585,118.50', '1960.93',
#        '1279.22', '523.71', '1098.62', '195.61', '1810.34', '4285.12',
#        '848.7', '1344.03', '220.75', '184.12', '243.33', '670.74',
# ...

# %%
givingTuesday['Annual Expenditure (Rs in lacs)'] = givingTuesday['Annual Expenditure (Rs in lacs)'].str.replace(r'\D', '')
# Out:
# C:\Users\shaya\AppData\Local\Temp\ipykernel_20004\3759091161.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   givingTuesday['Annual Expenditure (Rs in lacs)'] = givingTuesday['Annual Expenditure (Rs in lacs)'].str.replace(r'\D', '')

# %%
givingTuesday['Annual Expenditure (Rs in lacs)'].unique()
# Out:
# array([nan, '518', '18000000', '421671', '197067666', '434274',
#        '54979197', '8500000', '3000000', '9205922', '3853', '5298',
#        '45227220', '', '4569409', '8486', '464958', '44272000', '2574229',
#        '8', '5000000', '40256528', '6022233', '1324728', '4472700',
#        '262463300', '2675904', '2959117', '4300000', '7435647091',
#        '38365', '600000', '150', '1179', '1305239284', '15000000', '5',
#        '1810767', '25', '300000', '2048044', '4187879', '260000000',
#        '450721787', '3776029', '1028865', '180670360', '361000',
#        '3467049', '2847876', '1354000', '37549665', '5187129235',
#        '2500435', '1138977', '58511850', '196093', '127922', '52371',
#        '109862', '19561', '181034', '428512', '8487', '134403', '22075',
#        '18412', '24333', '67074', '30132', '43807', '22653', '12124',
#        '72359', '38363', '239908', '182823', '555', '132407', '10175',
#        '94777', '7531', '71889', '20379', '144068', '83887', '11139',
# ...

# %%
givingTuesday.head(10)
# Out:
#                                                  Url  \
# 0  https://www.givingtuesdayindia.org/ngo-detail/...
# 1  https://www.givingtuesdayindia.org/ngo-detail/...
# 2  https://www.givingtuesdayindia.org/ngo-detail/...
# 3  https://www.givingtuesdayindia.org/ngo-detail/...
# 4  https://www.givingtuesdayindia.org/ngo-detail/...
# 5  https://www.givingtuesdayindia.org/ngo-detail/...
# 6  https://www.givingtuesdayindia.org/ngo-detail/...
# 7  https://www.givingtuesdayindia.org/ngo-detail/...
# 8  https://www.givingtuesdayindia.org/ngo-detail/...
# 9  https://www.givingtuesdayindia.org/ngo-detail/...
#
#                                             NGO Name  \
# 0  `Sahaj' (An Organisation for Women's Development)
# 1  "DIVYA RASA" (Centre for Healing, Learning, Re...
# 2                      "Sankalp" Manav Vikas Sanstha
# 3  "VISHA" VOCATIONAL INSTITUTES SOCIAL,HEALTH AN...
# 4                                17000 ft Foundation
# 5                                 A New Friends Club
# ...

# %%
givingTuesday['Focus'].value_counts()
# Out:
# Rural & Urban    619
# Rural            189
# Urban             85
# Name: Focus, dtype: int64

# %%
focus_counts = givingTuesday['Focus'].value_counts()

# Plot the results as a bar chart
focus_counts.plot(kind='bar')

# Add labels and a title
plt.xlabel('Focus')
plt.ylabel('Count')
plt.title('NGOs by Focus')
plt.show()

# %% [markdown]
# Very large number of the total NGO's are located in Rural and Urban, and Rural areas. This is roughly 90 percent of the data.

# %%
print(619+189+85)
print(619+189)
print(808/893)
# Out:
# 893
# 808
# 0.9048152295632699

# %%
givingTuesday['Full Time Staff'] = givingTuesday['Full Time Staff'].str.extract('(\d+)')

givingTuesday['Full Time Staff'] = givingTuesday['Full Time Staff'].astype('Int64')

# %%
givingTuesday['Full Time Volunteers'] = givingTuesday['Full Time Volunteers'].astype('Int64')

# %%
givingTuesday['Cause(s)'].value_counts()
# Out:
# Education                                                                                                                     58
# Healthcare                                                                                                                    46
# Community Development                                                                                                         44
# Children, Education                                                                                                           34
# Education, Healthcare                                                                                                         20
#                                                                                                                               ..
# Education, Healthcare, Civic Issues                                                                                            1
# ...

# %%
cause_counts = givingTuesday['Cause(s)'].value_counts()

# Select the top 5 causes and their frequencies
top_causes = cause_counts.head(5)
top_cause_names = top_causes.index
top_cause_counts = top_causes.values

# Plot a bar chart of the top 5 causes
plt.bar(top_cause_names, top_cause_counts)
plt.title('Top 5 Most Frequent Causes')
plt.xticks(rotation=90)
plt.xlabel('Cause')
plt.ylabel('Frequency')
plt.show()

# %%
givingTuesday.columns
# Out:
# Index(['Url', 'NGO Name', 'Popular Name', 'Year of Establishment',
#        'GuideStar URL', 'Full Time Staff', 'Full Time Volunteers',
#        'Brief description', 'Annual Expenditure (Rs in lacs)',
#        'Year for Annual Expenditure', 'Impact', 'Profile pic',
#        'Organisation Website', 'Email', 'Telephone/ Mobile number',
#        'Correspondence  Address', 'Phone', 'Cause(s)',
#        'Nature of Intervention', 'Beneficairies', 'Focus',
#        'Area of Operation: State', 'PAN'],
#       dtype='object')

# %% [markdown]
# Experimenting with moving values from phone column to telephone column.

# %%
givingTuesday_Copy = givingTuesday.copy()
givingTuesday_Copy['Telephone/ Mobile number'].fillna(givingTuesday_Copy['Phone'], inplace=True)

# %%
givingTuesday_Copy.head()
# Out:
#                                                  Url  \
# 0  https://www.givingtuesdayindia.org/ngo-detail/...
# 1  https://www.givingtuesdayindia.org/ngo-detail/...
# 2  https://www.givingtuesdayindia.org/ngo-detail/...
# 3  https://www.givingtuesdayindia.org/ngo-detail/...
# 4  https://www.givingtuesdayindia.org/ngo-detail/...
#
#                                             NGO Name  \
# 0  `Sahaj' (An Organisation for Women's Development)
# 1  "DIVYA RASA" (Centre for Healing, Learning, Re...
# 2                      "Sankalp" Manav Vikas Sanstha
# 3  "VISHA" VOCATIONAL INSTITUTES SOCIAL,HEALTH AN...
# 4                                17000 ft Foundation
#
#                   Popular Name  Year of Establishment  \
# 0                        Sahaj                   2001
# 1  Divya Rasa - Temple of Love                   2015
# 2                          NaN                   1992
# 3                    VISHA NGO                   2012
# ...

# %%
givingTuesday['Telephone/ Mobile number'].fillna(givingTuesday['Phone'], inplace=True)

# %%
givingTuesday.head(1)
# Out:
#                                                  Url  \
# 0  https://www.givingtuesdayindia.org/ngo-detail/...
#
#                                             NGO Name Popular Name  \
# 0  `Sahaj' (An Organisation for Women's Development)        Sahaj
#
#    Year of Establishment                                      GuideStar URL  \
# 0                   2001  https://guidestarindia.org/Summary.aspx?CCReg=...
#
#    Full Time Staff  Full Time Volunteers  \
# 0               70                  <NA>
#
#                                    Brief description  \
# 0  Sahaj is an organization working for skill dev...
#
#   Annual Expenditure (Rs in lacs) Year for Annual Expenditure  ...  \
# 0                             NaN                         NaN  ...
#
#                    Email        Telephone/ Mobile number  \
# 0  admnsahaj@outlook.com  91-2673-245215, 91-2673-245215
#
#                              Correspondence  Address  \
# ...

# %%
givingTuesday.drop('Phone', axis=1, inplace=True)

# %%
givingTuesday.head(1)
# Out:
#                                                  Url  \
# 0  https://www.givingtuesdayindia.org/ngo-detail/...
#
#                                             NGO Name Popular Name  \
# 0  `Sahaj' (An Organisation for Women's Development)        Sahaj
#
#    Year of Establishment                                      GuideStar URL  \
# 0                   2001  https://guidestarindia.org/Summary.aspx?CCReg=...
#
#    Full Time Staff  Full Time Volunteers  \
# 0               70                  <NA>
#
#                                    Brief description  \
# 0  Sahaj is an organization working for skill dev...
#
#   Annual Expenditure (Rs in lacs) Year for Annual Expenditure  ...  \
# 0                             NaN                         NaN  ...
#
#         Organisation Website                  Email  \
# 0  http://www.sahajindia.org  admnsahaj@outlook.com
#
#          Telephone/ Mobile number  \
# 0  91-2673-245215, 91-2673-245215
#
# ...

# %% [markdown]
# Successfully dropped Phone column and merged data to Telephone col

# %%
givingTuesday.shape[1]
# Out:
# 22

# %%
givingTuesday.dtypes
# Out:
# Url                                object
# NGO Name                           object
# Popular Name                       object
# Year of Establishment               Int64
# GuideStar URL                      object
# Full Time Staff                     Int64
# Full Time Volunteers                Int64
# Brief description                  object
# Annual Expenditure (Rs in lacs)    object
# Year for Annual Expenditure        object
# Impact                             object
# Profile pic                        object
# Organisation Website               object
# Email                              object
# Telephone/ Mobile number           object
# Correspondence  Address            object
# Cause(s)                           object
# Nature of Intervention             object
# Beneficairies                      object
# Focus                              object
# Area of Operation: State           object
# PAN                                object
# dtype: object

# %% [markdown]
# Data cleaning for Annual expenditure col.

# %%
givingTuesday['Annual Expenditure (Rs in lacs)'] = givingTuesday['Annual Expenditure (Rs in lacs)'].replace('', np.nan)

givingTuesday['Annual Expenditure (Rs in lacs)'] = givingTuesday['Annual Expenditure (Rs in lacs)'].astype('Int64')

# %%
for col in givingTuesday.columns:
    print(col, ':', givingTuesday[col].nunique())
# Out:
# Url : 926
# NGO Name : 925
# Popular Name : 627
# Year of Establishment : 62
# GuideStar URL : 925
# Full Time Staff : 169
# Full Time Volunteers : 99
# Brief description : 903
# Annual Expenditure (Rs in lacs) : 158
# Year for Annual Expenditure : 4
# Impact : 466
# Profile pic : 186
# Organisation Website : 793
# Email : 923
# Telephone/ Mobile number : 732
# Correspondence  Address : 854
# Cause(s) : 349
# Nature of Intervention : 81
# Beneficairies : 783
# Focus : 3
# Area of Operation: State : 139
# PAN : 926

# %%
givingTuesday.to_csv('original_data.csv', index=False)
