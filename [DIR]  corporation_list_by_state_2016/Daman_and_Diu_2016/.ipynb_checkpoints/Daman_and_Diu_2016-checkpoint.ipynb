# %% [markdown]
# # Codebook
# **Authors:** Lauren Baker
# Documenting existing data files of DaanMatch with information about location, owner, "version", source etc.

# %%
import boto3
import numpy as np 
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import statistics

# %%
client = boto3.client('s3')
resource = boto3.resource('s3')
my_bucket = resource.Bucket('daanmatchdatafiles')

# %% [markdown]
# # Daman_and_Diu_2016.xlsx
#
# ## TOC:
# * [About this dataset](#1)
# * [What's in this dataset](#2)
# * [Codebook](#3)
#     * [Missing values](#3.1)
#     * [Summary statistics](#3.2)
# * [Columns](#4)
#     * [CIN](#4.1)
#     * [COMPANY_NAME](#4.2)
#     * [COMPANY_CLASS](#4.3)
#     * [COMPANY_CATEGORY](#4.4)
#     * [COMPANY_SUBCAT](#4.5)
#     * [COMPANY_STATUS](#4.6)
#     * [DATE_OF_REGISTRATION](#4.7)
#     * [REGISTERED_STATE](#4.8)
#     * [Authorized Capital  (Rs.)](#4.9)
#     * [PAIDUP_CAPITAL (Rs.)](#4.10)
#     * [PRINCIPAL_BUSINESS_ACTIVITY_CODE](#4.11)
#     * [REGISTERED_OFFICE_ADDRESS](#4.12)
#     * [EMAIL_ID](#4.13)
#     * [LATEST ANNUAL REPORT FILING FY END DATE](#4.14)
#     * [LATEST BALANCE SHEET FILING FY END DATE](#4.15)

# %% [markdown]
# **About this dataset**  <a class="anchor" id="1"></a>
# Data provided by: MCA
# Source: https://daanmatchdatafiles.s3.us-west-1.amazonaws.com/DaanMatch_DataFiles/Daman_and_Diu_2016.xlsx
# Type: xlsx
# Last Modified: May 29, 2021, 22:54:16 (UTC-04:00)
# Size: 59.7 KB

# %%
path = "s3://daanmatchdatafiles/DaanMatch_DataFiles/Daman_and_Diu_2016.xlsx"
Daman_Diu_2016 = pd.ExcelFile(path)
print(Daman_Diu_2016.sheet_names)
# Combine both sheets
Daman_Diu_2016 = Daman_Diu_2016.parse('Sheet3')
Daman_Diu_2016.head()
# Out:
# ['Sheet3']
#                      CIN                              COMPANY_NAME  \
# 0  U31909DD1998PLC004665                     NED ENERGY LIMITED
# 1  U74110DD2005PTC004676  BAGHBAAN DISTRIBUTORS PRIVATE LIMITED
# 2  L25209DD1992PLC009784          TOKYO PLAST INTERNATIONAL LTD
# 3  L65923DD1994PLC009783                  TOKYO FINANCE LIMITED
# 4  U51900DD1999PTC009780     CITADELLE AGENCIES PRIVATE LIMITED
#
#   COMPANY_CLASS           COMPANY_CATEGORY    COMPANY_SUBCAT COMPANY_STATUS  \
# 0        Public  Company limited by Shares  Non-govt company         ACTIVE
# 1       Private  Company limited by Shares  Non-govt company         ACTIVE
# 2        Public  Company limited by Shares  Non-govt company         ACTIVE
# 3        Public  Company limited by Shares  Non-govt company         ACTIVE
# 4       Private  Company limited by Shares  Non-govt company         ACTIVE
#
#   DATE_OF_REGISTRATION REGISTERED_STATE  Authorized Capital  (Rs.)  \
# 0           1998-12-11    Daman and Diu                  325000000
# 1           2005-01-31    Daman and Diu                   10000000
# 2           1992-11-18    Daman and Diu                  250000000
# 3           1994-11-22    Daman and Diu                  725000000
# 4           1999-08-09    Daman and Diu                  973500000
#
#     PAIDUP_CAPITAL (RS.)  PRINCIPAL_BUSINESS_ACTIVITY_CODE  \
# 0               65806450                             31909
# 1                4700000                             74110
# 2               95014000                             25209
# 3               69425500                             65923
# 4              425988930                             51900
#
#                            REGISTERED_OFFICE_ADDRESS  \
# 0                       213,SABARI  KACHGAM IN396210
# 1  105, PUSHPANAJALI APARTMENTSAI KRUPA SOCIETY, ...
# 2  363/1(1,2,3), SHREE GANESH INDUSTRIAL ESTATEKA...
# 3  363/1(1,2,3), SHREE GANESH INDUSTRIAL ESTATEKA...
# 4  Office No.141, Center Point,Somnath  DamanDama...
#
#                               EMAIL_ID  \
# 0           darshanvoraandco@gmail.com
# 1               jaindeepak13@gmail.com
# 2                 parul@tokyoplast.com
# 3          info.tokyofinance@gmail.com
# 4  sandeep.bhanushali@dolatcapital.com
#
#   LATEST ANNUAL REPORT FILING FY END DATE  \
# 0                              2015-03-31
# 1                              2015-03-31
# 2                              2015-03-31
# 3                              2015-03-31
# 4                              2015-03-31
#
#   LATEST BALANCE SHEET FILING FY END DATE
# 0                              2015-03-31
# 1                              2016-03-31
# 2                              2016-03-31
# 3                              2016-03-31
# 4                              2015-03-31

# %% [markdown]
# **What's in this dataset?** <a class="anchor" id="2"></a>

# %%
print("Shape:", Daman_Diu_2016.shape)
print("Rows:", Daman_Diu_2016.shape[0])
print("Columns:", Daman_Diu_2016.shape[1])
print("Each row is a company.")
# Out:
# Shape: (327, 15)
# Rows: 327
# Columns: 15
# Each row is a company.

# %% [markdown]
# **Codebook** <a class="anchor" id="3"></a>

# %%
Daman_Diu_2016_columns = [column for column in Daman_Diu_2016.columns]
Daman_Diu_2016_description = ["Corporate Identification Number in India (CIN) is a 21 digit alpha-numeric code issued to companies incorporated within India on being registered with Registrar of Companies (RCA).",
                                           "Name of Company.",
                                           "Class of Company: Private or Public.",
                                           "Category of Company: Limited by Shares, Limited by Guarantee, Unlimited Company.",
                                           "Subcategory of Company: Non-govt, Union Gtvt, State Govt, Subsidiary of Foreign Company, Guarantee and Association Company.",
                                           "Status of Company.",
                                           "Timestamp of date of registration: YYYY-MM-DD HH:MM:SS.",
                                           "State of registration.",
                                           "Authorized capital in rupees (Rs.).",
                                           "Paid up capital in rupees (Rs.).",
                                           "Principal Business code that classifies the main type of product/service sold.",
                                           "Address of registered office.",
                                           "Company email.",
                                           "Latest annual report filing fiscal year end date: YYYY-MM-DD.",
                                           "Latest balance sheet filing fiscal year end date: YYYY-MM-DD."]
Daman_Diu_2016_dtypes = [dtype for dtype in Daman_Diu_2016.dtypes]

data = {"Column Name": Daman_Diu_2016_columns, "Description": Daman_Diu_2016_description, "Type": Daman_Diu_2016_dtypes}
Daman_Diu_2016_codebook = pd.DataFrame(data)
Daman_Diu_2016_codebook.style.set_properties(subset=['Description'], **{'width': '600px'})
# Out:
# <style  type="text/css" >
# #T_788de_row0_col1,#T_788de_row1_col1,#T_788de_row2_col1,#T_788de_row3_col1,#T_788de_row4_col1,#T_788de_row5_col1,#T_788de_row6_col1,#T_788de_row7_col1,#T_788de_row8_col1,#T_788de_row9_col1,#T_788de_row10_col1,#T_788de_row11_col1,#T_788de_row12_col1,#T_788de_row13_col1,#T_788de_row14_col1{
#             width:  600px;
#         }</style><table id="T_788de_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Column Name</th>        <th class="col_heading level0 col1" >Description</th>        <th class="col_heading level0 col2" >Type</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_788de_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_788de_row0_col0" class="data row0 col0" >CIN</td>
#                         <td id="T_788de_row0_col1" class="data row0 col1" >Corporate Identification Number in India (CIN) is a 21 digit alpha-numeric code issued to companies incorporated within India on being registered with Registrar of Companies (RCA).</td>
#                         <td id="T_788de_row0_col2" class="data row0 col2" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_788de_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_788de_row1_col0" class="data row1 col0" >COMPANY_NAME</td>
#                         <td id="T_788de_row1_col1" class="data row1 col1" >Name of Company.</td>
#                         <td id="T_788de_row1_col2" class="data row1 col2" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_788de_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_788de_row2_col0" class="data row2 col0" >COMPANY_CLASS</td>
#                         <td id="T_788de_row2_col1" class="data row2 col1" >Class of Company: Private or Public.</td>
#                         <td id="T_788de_row2_col2" class="data row2 col2" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_788de_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_788de_row3_col0" class="data row3 col0" >COMPANY_CATEGORY</td>
#                         <td id="T_788de_row3_col1" class="data row3 col1" >Category of Company: Limited by Shares, Limited by Guarantee, Unlimited Company.</td>
#                         <td id="T_788de_row3_col2" class="data row3 col2" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_788de_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_788de_row4_col0" class="data row4 col0" >COMPANY_SUBCAT</td>
#                         <td id="T_788de_row4_col1" class="data row4 col1" >Subcategory of Company: Non-govt, Union Gtvt, State Govt, Subsidiary of Foreign Company, Guarantee and Association Company.</td>
#                         <td id="T_788de_row4_col2" class="data row4 col2" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_788de_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_788de_row5_col0" class="data row5 col0" >COMPANY_STATUS</td>
#                         <td id="T_788de_row5_col1" class="data row5 col1" >Status of Company.</td>
#                         <td id="T_788de_row5_col2" class="data row5 col2" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_788de_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_788de_row6_col0" class="data row6 col0" >DATE_OF_REGISTRATION</td>
#                         <td id="T_788de_row6_col1" class="data row6 col1" >Timestamp of date of registration: YYYY-MM-DD HH:MM:SS.</td>
#                         <td id="T_788de_row6_col2" class="data row6 col2" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_788de_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_788de_row7_col0" class="data row7 col0" >REGISTERED_STATE</td>
#                         <td id="T_788de_row7_col1" class="data row7 col1" >State of registration.</td>
#                         <td id="T_788de_row7_col2" class="data row7 col2" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_788de_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_788de_row8_col0" class="data row8 col0" >Authorized Capital  (Rs.)</td>
#                         <td id="T_788de_row8_col1" class="data row8 col1" >Authorized capital in rupees (Rs.).</td>
#                         <td id="T_788de_row8_col2" class="data row8 col2" >int64</td>
#             </tr>
#             <tr>
#                         <th id="T_788de_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_788de_row9_col0" class="data row9 col0" > PAIDUP_CAPITAL (RS.)</td>
#                         <td id="T_788de_row9_col1" class="data row9 col1" >Paid up capital in rupees (Rs.).</td>
#                         <td id="T_788de_row9_col2" class="data row9 col2" >int64</td>
#             </tr>
#             <tr>
#                         <th id="T_788de_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_788de_row10_col0" class="data row10 col0" >PRINCIPAL_BUSINESS_ACTIVITY_CODE</td>
#                         <td id="T_788de_row10_col1" class="data row10 col1" >Principal Business code that classifies the main type of product/service sold.</td>
#                         <td id="T_788de_row10_col2" class="data row10 col2" >int64</td>
#             </tr>
#             <tr>
#                         <th id="T_788de_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_788de_row11_col0" class="data row11 col0" >REGISTERED_OFFICE_ADDRESS</td>
#                         <td id="T_788de_row11_col1" class="data row11 col1" >Address of registered office.</td>
#                         <td id="T_788de_row11_col2" class="data row11 col2" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_788de_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_788de_row12_col0" class="data row12 col0" >EMAIL_ID</td>
#                         <td id="T_788de_row12_col1" class="data row12 col1" >Company email.</td>
#                         <td id="T_788de_row12_col2" class="data row12 col2" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_788de_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_788de_row13_col0" class="data row13 col0" >LATEST ANNUAL REPORT FILING FY END DATE</td>
#                         <td id="T_788de_row13_col1" class="data row13 col1" >Latest annual report filing fiscal year end date: YYYY-MM-DD.</td>
#                         <td id="T_788de_row13_col2" class="data row13 col2" >object</td>
#             </tr>
#             <tr>
#                         <th id="T_788de_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_788de_row14_col0" class="data row14 col0" >LATEST BALANCE SHEET FILING FY END DATE</td>
#                         <td id="T_788de_row14_col1" class="data row14 col1" >Latest balance sheet filing fiscal year end date: YYYY-MM-DD.</td>
#                         <td id="T_788de_row14_col2" class="data row14 col2" >object</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# **Missing values** <a class="anchor" id="3.1"></a>

# %%
Daman_Diu_2016.isnull().sum()
# Out:
# CIN                                        0
# COMPANY_NAME                               0
# COMPANY_CLASS                              0
# COMPANY_CATEGORY                           0
# COMPANY_SUBCAT                             0
# COMPANY_STATUS                             0
# DATE_OF_REGISTRATION                       0
# REGISTERED_STATE                           0
# Authorized Capital  (Rs.)                  0
#  PAIDUP_CAPITAL (RS.)                      0
# PRINCIPAL_BUSINESS_ACTIVITY_CODE           0
# REGISTERED_OFFICE_ADDRESS                  0
# EMAIL_ID                                   0
# LATEST ANNUAL REPORT FILING FY END DATE    0
# LATEST BALANCE SHEET FILING FY END DATE    0
# dtype: int64

# %% [markdown]
# **Summary statistics** <a class="anchor" id="3.2"></a>

# %%
Daman_Diu_2016.describe()
# Out:
#        Authorized Capital  (Rs.)   PAIDUP_CAPITAL (RS.)  \
# count               3.270000e+02           3.270000e+02
# mean                6.330749e+07           4.258602e+07
# std                 2.503610e+08           2.212552e+08
# min                 0.000000e+00           0.000000e+00
# 25%                 5.000000e+05           1.000000e+05
# 50%                 3.000000e+06           5.000000e+05
# 75%                 3.125000e+07           1.200075e+07
# max                 3.600000e+09           3.520000e+09
#
#        PRINCIPAL_BUSINESS_ACTIVITY_CODE
# count                        327.000000
# mean                       38976.477064
# std                        24859.376362
# min                            6.000000
# 25%                        24184.500000
# 50%                        36101.000000
# 75%                        65923.000000
# max                        93000.000000

# %% [markdown]
# ## Columns
# <a class="anchor" id="4"></a>

# %% [markdown]
# ### CIN
# <a class="anchor" id="4.1"></a>
# Corporate Identification Number in India (CIN) is a 21 digit alpha-numeric code issued to companies incorporated within India on being registered with Registrar of Companies (RCA).

# %%
column = Daman_Diu_2016["CIN"]
column
# Out:
# 0      U31909DD1998PLC004665
# 1      U74110DD2005PTC004676
# 2      L25209DD1992PLC009784
# 3      L65923DD1994PLC009783
# 4      U51900DD1999PTC009780
#                ...
# 322    U51101DD2012PTC004743
# 323    L67100DD1983PLC004760
# 324    U93000DD2009PTC004753
# 325    U65992DD2011PTC004761
# 326    U74140DD2010PTC004741
# Name: CIN, Length: 327, dtype: object

# %%
# Check if all rows have 21 digits
CIN_length = [len(CIN) for CIN in column]
print("Rows without 21 digits:", sum([length != 21 for length in CIN_length]))

print("No. of unique values:", len(column.unique()))

# Check for duplicates
counter = dict(Counter(column))
duplicates = { key:value for key, value in counter.items() if value > 1}
print("Duplicates:", duplicates)
# Out:
# Rows without 21 digits: 0
# No. of unique values: 327
# Duplicates: {}

# %% [markdown]
# ### COMPANY_NAME
# <a class="anchor" id="4.2"></a>
# Name of Company.
# There is trailing and leading whitespace. Need to strip strings.

# %%
column = Daman_Diu_2016["COMPANY_NAME"]
column
# Out:
# 0                          NED ENERGY LIMITED
# 1       BAGHBAAN DISTRIBUTORS PRIVATE LIMITED
# 2               TOKYO PLAST INTERNATIONAL LTD
# 3                       TOKYO FINANCE LIMITED
# 4          CITADELLE AGENCIES PRIVATE LIMITED
#                          ...
# 322            VIPRIT TRADING PRIVATE LIMITED
# 323                 DOLAT INVESTMENTS LIMITED
# 324     TRADEBULLS SECURITIES PRIVATE LIMITED
# 325             SABRANG CHITS PRIVATE LIMITED
# 326    SNT DERIVATIVE BROKING PRIVATE LIMITED
# Name: COMPANY_NAME, Length: 327, dtype: object

# %%
# Strip strings
stripped_name = column.str.strip()
print("Invalid names:", sum(stripped_name.isnull()))

print("No. of unique values:", len(column.unique()))

# Check for duplicates
counter = dict(Counter(column))
duplicates = { key:value for key, value in counter.items() if value > 1}
print("Duplicates:", duplicates)
if len(duplicates) > 0:
    print("No. of duplicates:", len(duplicates))
# Out:
# Invalid names: 0
# No. of unique values: 326
# Duplicates: {'DAMAN NEWS LINE PRIVATE LIMITED   ': 2}
# No. of duplicates: 1

# %%
Daman_Diu_2016[Daman_Diu_2016["COMPANY_NAME"].isin(duplicates)]
# Out:
#                        CIN                        COMPANY_NAME COMPANY_CLASS  \
# 215  U22122DD2004PTC003566  DAMAN NEWS LINE PRIVATE LIMITED          Private
# 216  U22122DD2004PTC002731  DAMAN NEWS LINE PRIVATE LIMITED          Private
#
#               COMPANY_CATEGORY    COMPANY_SUBCAT  \
# 215  Company limited by Shares  Non-govt company
# 216  Company limited by Shares  Non-govt company
#
#                             COMPANY_STATUS DATE_OF_REGISTRATION  \
# 215                                 ACTIVE           2004-07-29
# 216  INACTIVE UNDER SECTION 455 OF CA,2013           2004-07-29
#
#     REGISTERED_STATE  Authorized Capital  (Rs.)   PAIDUP_CAPITAL (RS.)  \
# 215    Daman and Diu                     500000                 100000
# 216    Daman and Diu                     500000                 100000
#
#      PRINCIPAL_BUSINESS_ACTIVITY_CODE  \
# 215                             22122
# 216                             22122
#
#                              REGISTERED_OFFICE_ADDRESS  \
# 215  DABHEL CHECK POST,DABHEL-NANI DAMAN,  DAMAN IN...
# 216                 GHELWADFALIADABHEL  DAMAN IN396215
#
#                     EMAIL_ID LATEST ANNUAL REPORT FILING FY END DATE  \
# 215  gulati_dinesh@yahoo.com                              2013-03-31
# 216                                                                0
#
#     LATEST BALANCE SHEET FILING FY END DATE
# 215                              2013-03-31
# 216                                       0

# %% [markdown]
# The one duplicate in ```COMPANY_NAME``` appears to be the same company, yet one is inactive and one is active.

# %% [markdown]
# ### COMPANY_CLASS
# <a class="anchor" id="4.3"></a>
# Class of Company: Private or Public.

# %%
column = Daman_Diu_2016["COMPANY_CLASS"]
column
# Out:
# 0       Public
# 1      Private
# 2       Public
# 3       Public
# 4      Private
#         ...
# 322    Private
# 323     Public
# 324    Private
# 325    Private
# 326    Private
# Name: COMPANY_CLASS, Length: 327, dtype: object

# %%
print("Unique values:", column.unique())
print("No. of unique values:", len(column.unique()))

# Number of empty strings
print("Empty strings:", sum(column == " "))

# Table of number of each class
table = column.value_counts().rename_axis('Class').reset_index(name='Count')
table
# Out:
# Unique values: ['Public' 'Private' 'Private(One Person Company)']
# No. of unique values: 3
# Empty strings: 0
#                          Class  Count
# 0                      Private    258
# 1                       Public     68
# 2  Private(One Person Company)      1

# %%
# Plot number of each class
plt.figure(figsize = (8, 6))
plt.bar(table["Class"], table["Count"])
plt.title("Count of Company Classes")
plt.xlabel("Class");

# %% [markdown]
# ### COMPANY_CATEGORY
# <a class="anchor" id="4.4"></a>
# Category of Company: Limited by Shares, Limited by Guarantee, Unlimited Company.

# %%
column = Daman_Diu_2016["COMPANY_CATEGORY"]
column
# Out:
# 0      Company limited by Shares
# 1      Company limited by Shares
# 2      Company limited by Shares
# 3      Company limited by Shares
# 4      Company limited by Shares
#                  ...
# 322    Company limited by Shares
# 323    Company limited by Shares
# 324    Company limited by Shares
# 325    Company limited by Shares
# 326    Company limited by Shares
# Name: COMPANY_CATEGORY, Length: 327, dtype: object

# %%
print("Unique values:", column.unique())
print("No. of unique values:", len(column.unique()))

# Number of empty strings
print("Empty strings:", sum(column == " "))

# Table of number of each category
table = column.value_counts().rename_axis('Category').reset_index(name='Count')
table
# Out:
# Unique values: ['Company limited by Shares' 'Company Limited by Guarantee']
# No. of unique values: 2
# Empty strings: 0
#                        Category  Count
# 0     Company limited by Shares    325
# 1  Company Limited by Guarantee      2

# %%
# Plot number of each Category
plt.figure(figsize = (8, 6))
plt.bar(table["Category"], table["Count"])
plt.title("Count of Company Categories")
plt.xlabel("Category")
plt.xticks(rotation = 20);

# %% [markdown]
# ### COMPANY_SUBCAT
# <a class="anchor" id="4.5"></a>
# Subcategory of Company: Non-govt, Union Gtvt, State Govt, Subsidiary of Foreign Company, Guarantee and Association Company.

# %%
column = Daman_Diu_2016["COMPANY_SUBCAT"]
column
# Out:
# 0      Non-govt company
# 1      Non-govt company
# 2      Non-govt company
# 3      Non-govt company
# 4      Non-govt company
#              ...
# 322    Non-govt company
# 323    Non-govt company
# 324    Non-govt company
# 325    Non-govt company
# 326    Non-govt company
# Name: COMPANY_SUBCAT, Length: 327, dtype: object

# %%
print("Unique values:", column.unique())
print("No. of unique values:", len(column.unique()))

# Number of empty strings
print("Empty strings:", sum(column == " "))

# Table of number of each sub-category
table = column.value_counts().rename_axis('Sub-category').reset_index(name='Count')
table
# Out:
# Unique values: ['Non-govt company' 'State Govt company' 'Guarantee and Association comp']
# No. of unique values: 3
# Empty strings: 0
#                      Sub-category  Count
# 0                Non-govt company    324
# 1              State Govt company      2
# 2  Guarantee and Association comp      1

# %%
# Plot number of each sub-category
plt.figure(figsize = (8, 6))
plt.bar(table["Sub-category"], table["Count"])
plt.title("Count of Company Sub-categories")
plt.xlabel("Sub-category")
plt.xticks(rotation = 20);

# %% [markdown]
# ### COMPANY_STATUS
# <a class="anchor" id="4.6"></a>
# Status of Company.

# %%
column = Daman_Diu_2016["COMPANY_STATUS"]
column
# Out:
# 0      ACTIVE
# 1      ACTIVE
# 2      ACTIVE
# 3      ACTIVE
# 4      ACTIVE
#         ...
# 322    ACTIVE
# 323    ACTIVE
# 324    ACTIVE
# 325    ACTIVE
# 326    ACTIVE
# Name: COMPANY_STATUS, Length: 327, dtype: object

# %%
print("Unique values:", column.unique())
print("No. of unique values:", len(column.unique()))

# Number of empty strings
print("Empty strings:", sum(column == " "))

# Table of number of each status
counter = dict(Counter(column))
count = { key:[value] for key, value in counter.items()}
table = pd.DataFrame.from_dict(count).rename(columns={" ": "Empty"})
table = table.melt(var_name="Status", value_name="Count")
table
# Out:
# Unique values: ['ACTIVE' 'STRUCK-OFF' 'UNDER LIQUIDATION' 'UNDER PROCESS OF STRUCK-OFF'
#  'INACTIVE UNDER SECTION 455 OF CA,2013' 'CONVERTED TO LLP AND DISSOLVED'
#  'AMALGAMATED' 'LIQUIDATED' 'DORMANT UNDER SECTION 455 OF CA,2013']
# No. of unique values: 9
# Empty strings: 0
#                                   Status  Count
# 0                                 ACTIVE    214
# 1                             STRUCK-OFF     52
# 2                      UNDER LIQUIDATION      3
# 3            UNDER PROCESS OF STRUCK-OFF     34
# 4  INACTIVE UNDER SECTION 455 OF CA,2013     14
# 5         CONVERTED TO LLP AND DISSOLVED      2
# 6                            AMALGAMATED      6
# 7                             LIQUIDATED      1
# 8   DORMANT UNDER SECTION 455 OF CA,2013      1

# %%
# Plot number of each status
plt.figure(figsize = (8, 6))
plt.bar(table["Status"], table["Count"])
plt.title("Count of Company Statuses")
plt.xlabel("Status")
plt.xticks(rotation = 90);

# %% [markdown]
# ### DATE_OF_REGISTRATION
# <a class="anchor" id="4.7"></a>
# Timestamp of date of registration.

# %%
column = Daman_Diu_2016["DATE_OF_REGISTRATION"]
column
# Out:
# 0      1998-12-11
# 1      2005-01-31
# 2      1992-11-18
# 3      1994-11-22
# 4      1999-08-09
#           ...
# 322    2012-11-27
# 323    1983-02-24
# 324    2009-06-09
# 325    2011-07-26
# 326    2010-09-13
# Name: DATE_OF_REGISTRATION, Length: 327, dtype: object

# %%
# Number of null values
print("Null:", sum(column.isnull()))

# Drop null values
cleaned = column.dropna()
# Convert all objects to str in YYYY-MM-DD format
dates = cleaned.astype(str).apply(lambda x: x[:10])

# Range
print("Min:", min(dates))
print("Max:", max(dates))
# Out:
# Null: 0
# Min: 1945-02-07
# Max: 2016-10-03

# %%
years = dates.apply(lambda x: int(x[:4]))
# Table of number of each year
counter = dict(Counter(years))
count = { key:[value] for key, value in counter.items()}
table = pd.DataFrame.from_dict(count)
table = table.melt(var_name="Date", value_name="Count")
print("No. of unique values:", table.shape[0])
table
# Out:
# No. of unique values: 42
#     Date  Count
# 0   1998      9
# 1   2005     10
# 2   1992     15
# 3   1994     20
# 4   1999     15
# 5   2006      3
# 6   2007      7
# 7   1988     16
# 8   2010     12
# 9   2013     18
# 10  2012     11
# 11  2015      9
# 12  2014      7
# 13  2003     10
# 14  2002      3
# 15  1996     15
# 16  1995     19
# 17  2008     10
# 18  1993     16
# 19  2004     10
# 20  2011     12
# 21  2000      8
# 22  2009      8
# 23  1990      2
# 24  1989     10
# 25  1997      9
# 26  1982      4
# 27  1991      4
# 28  1986      3
# 29  1981      2
# 30  1979      2
# 31  1975      4
# 32  1987      5
# 33  2016      8
# 34  1972      1
# 35  1984      1
# 36  1983      2
# 37  1971      1
# 38  1978      1
# 39  1985      2
# 40  2001      2
# 41  1945      1

# %%
# Plot of number of each year
plt.figure(figsize = (10, 8))
plt.bar(table["Date"], np.log(table["Count"]))
plt.title("Count of Log year of registration")
plt.ylabel("Log Count")
plt.xlabel("Year");

# %% [markdown]
# ### REGISTERED_STATE
# <a class="anchor" id="4.8"></a>
# State of registration.

# %%
column = Daman_Diu_2016["REGISTERED_STATE"]
column
# Out:
# 0      Daman and Diu
# 1      Daman and Diu
# 2      Daman and Diu
# 3      Daman and Diu
# 4      Daman and Diu
#            ...
# 322    Daman and Diu
# 323    Daman and Diu
# 324    Daman and Diu
# 325    Daman and Diu
# 326    Daman and Diu
# Name: REGISTERED_STATE, Length: 327, dtype: object

# %%
print("Unique values:", column.unique())
print("No. of unique values:", len(column.unique()))

# Number of empty strings
print("Empty strings:", sum(column == " "))

# Table of number of each state
counter = dict(Counter(column))
count = { key:[value] for key, value in counter.items()}
table = pd.DataFrame.from_dict(count).rename(columns={" ": "Empty"})
table = table.melt(var_name="State", value_name="Count")
table
# Out:
# Unique values: ['Daman and Diu']
# No. of unique values: 1
# Empty strings: 0
#            State  Count
# 0  Daman and Diu    327

# %% [markdown]
# ### Authorized Capital  (Rs.)
# <a class="anchor" id="4.9"></a>
# Authorized capital in rupees (Rs.). Note that there are two white spaces between Capital and (Rs.) in column title.

# %%
column = Daman_Diu_2016["Authorized Capital  (Rs.)"]
column
# Out:
# 0      325000000
# 1       10000000
# 2      250000000
# 3      725000000
# 4      973500000
#          ...
# 322       100000
# 323    181000000
# 324     32500000
# 325       100000
# 326      5500000
# Name: Authorized Capital  (Rs.), Length: 327, dtype: int64

# %%
# Number of 0 values
print("0 Capital:", sum(column == 0))
print("No. of unique values:", len(column.unique()))

# Summary Statistics
print("Min:", min(column))
print("Max:", max(column))
print("Mean:", statistics.mean(column))
print("Mode:", statistics.mode(column))
print("Median:", statistics.median(column))
# Out:
# 0 Capital: 1
# No. of unique values: 83
# Min: 0
# Max: 3600000000
# Mean: 63307488.318042815
# Mode: 100000
# Median: 3000000

# %%
plt.figure(figsize = (10, 8))
column.plot.box()
plt.title("Box plot of Authorized capital (Rs.)")
plt.show()

# %%
logged = column.apply(lambda x: np.log(x))
plt.figure(figsize = (10, 8))
logged.plot.box()
plt.title("Box plot of Log of Authorized capital (Rs.)")
plt.show()

# %% [markdown]
# ### PAIDUP_CAPITAL (Rs.)
# <a class="anchor" id="4.10"></a>
# Paid up capital in rupees (Rs.). Note: leading whitespace in column title.

# %%
column = Daman_Diu_2016[" PAIDUP_CAPITAL (RS.)"]
column
# Out:
# 0       65806450
# 1        4700000
# 2       95014000
# 3       69425500
# 4      425988930
#          ...
# 322       100000
# 323    176000000
# 324     31250000
# 325       100000
# 326      3950000
# Name:  PAIDUP_CAPITAL (RS.), Length: 327, dtype: int64

# %%
# Number of 0 values
print("0 Capital:", sum(column == 0))
print("No. of unique values:", len(column.unique()))

# Summary Statistics
print("Min:", min(column))
print("Max:", max(column))
print("Mean:", statistics.mean(column))
print("Mode:", statistics.mode(column))
print("Median:", statistics.median(column))
# Out:
# 0 Capital: 38
# No. of unique values: 168
# Min: 0
# Max: 3520000000
# Mean: 42586023.18348624
# Mode: 100000
# Median: 500000

# %%
plt.figure(figsize = (10, 8))
column.plot.box()
plt.title("Box plot of Paid up capital (Rs.)")
plt.show()

# %%
logged = column.apply(lambda x: np.log(x))
plt.figure(figsize = (10, 8))
logged.plot.box()
plt.title("Box plot of Log of Paid up capital (Rs.)")
plt.show()

# %% [markdown]
# ### PRINCIPAL_BUSINESS_ACTIVITY_CODE
# <a class="anchor" id="4.11"></a>
# Principal Business code that classifies the main type of product/service sold.

# %%
column = Daman_Diu_2016["PRINCIPAL_BUSINESS_ACTIVITY_CODE"]
column
# Out:
# 0      31909
# 1      74110
# 2      25209
# 3      65923
# 4      51900
#        ...
# 322    51101
# 323    67100
# 324    93000
# 325    65992
# 326    74140
# Name: PRINCIPAL_BUSINESS_ACTIVITY_CODE, Length: 327, dtype: int64

# %%
print("No. of unique values:", len(column.unique()))
print("Min:", min(column))
print("Max:", max(column))

# Table of number of each Principal Business Activity Code
counter = dict(Counter(column))
count = { key:[value] for key, value in counter.items()}
table = pd.DataFrame.from_dict(count).rename(columns={" ": "Empty"})
table = table.melt(var_name="Principal Business Activity Code", value_name="Count").sort_values(by=["Count"], ascending=False).reset_index(drop=True)
table
# Out:
# No. of unique values: 161
# Min: 6
# Max: 93000
#      Principal Business Activity Code  Count
# 0                               25209     21
# 1                               67120     14
# 2                               74999     10
# 3                               55101     10
# 4                               51909     10
# ..                                ...    ...
# 156                             26103      1
# 157                             26104      1
# 158                             26931      1
# 159                             27101      1
# 160                             74140      1
#
# [161 rows x 2 columns]

# %% [markdown]
# ### REGISTERED_OFFICE_ADDRESS
# <a class="anchor" id="4.12"></a>
# Address of registered office.

# %%
column = Daman_Diu_2016["REGISTERED_OFFICE_ADDRESS"]
column
# Out:
# 0                           213,SABARI  KACHGAM IN396210
# 1      105, PUSHPANAJALI APARTMENTSAI KRUPA SOCIETY, ...
# 2      363/1(1,2,3), SHREE GANESH INDUSTRIAL ESTATEKA...
# 3      363/1(1,2,3), SHREE GANESH INDUSTRIAL ESTATEKA...
# 4      Office No.141, Center Point,Somnath  DamanDama...
#                              ...
# 322    342, CHORO MITHABAVA,GHOGHALA DIU, GHOGHALA  D...
# 323    Office No.141, Center Point,Somnath  Daman IN3...
# 324    Flat No. 304, "SAI NIVAS-C"   KathiriaDamanIN3...
# 325    ABHILASHA COMPLEX, H-NO.15/24/A, SHOP NO.4KHAR...
# 326    Flat No. 133,Ansal Chamber-II, Bhikaji Cama Pl...
# Name: REGISTERED_OFFICE_ADDRESS, Length: 327, dtype: object

# %%
# Number of invalid addresses
print("Invalid:", sum(column == "      IN"))
# -1 from invalid value
print("No. of unique values:", len(column.unique()) - 1)
# Out:
# Invalid: 0
# No. of unique values: 305

# %%
# Check for duplicates
counter = dict(Counter(column))
duplicates = { key:[value] for key, value in counter.items() if value > 1}
print("No. of Duplicates:", len(duplicates))

table = pd.DataFrame.from_dict(duplicates)
table = table.melt(var_name="Duplicate Registered Office Addresses", value_name="Count").sort_values(by=["Count"], ascending=False).reset_index(drop=True)
table
# Out:
# No. of Duplicates: 15
#                 Duplicate Registered Office Addresses  Count
# 0   Office No.141, Center Point,Somnath  DamanDama...      4
# 1   Plot No. 33, Daman Patalia Road,Bhimpore  Dama...      4
# 2   Plot No. 33, Unit-II,Silver Industrial Estate,...      3
# 3   SHOP NO. 15, SHANTINIKETAN BUILDING,KEVDI FALI...      3
# 4   363/1(1,2,3), SHREE GANESH INDUSTRIAL ESTATEKA...      2
# 5   Office No. 112, 1st Floor, Fortune Gee Bee Com...      2
# 6   Balasaheb P Daund,Prajapati Complex,Road No.10...      2
# 7   105, PUSHPANAJALI APPARTMENT, SAI KRUPA SOCIET...      2
# 8   PLOT NO. 33, DAMAN PATALIA ROAD,BHIMPORE  DAMA...      2
# 9   PLOT NO. 33, DAMAN PATALIA ROAD,BHIMPORE, DAMA...      2
# 10  139ANDRUL INDUSTRIAL ESTATESILVASSA  DAMAN IN3...      2
# 11  A2-4, DAMAN INDUSTRIAL ESTATE,DAMAN.   DAMAN. IN0      2
# 12  H. NO. 7/5 - 11A, 1ST FLOOR, SHIV SAGAR BUILDI...      2
# 13  Shop No 9, Somnath Commercial CenterVapi Daman...      2
# 14  Flat No. 304, "SAI NIVAS-C"   KathiriaDamanIN3...      2

# %%
Daman_Diu_2016[Daman_Diu_2016["REGISTERED_OFFICE_ADDRESS"].isin(duplicates)].sort_values('REGISTERED_OFFICE_ADDRESS')
# Out:
#                        CIN                                       COMPANY_NAME  \
# 73   U01122DD2010PTC004681              DHRUV AGRICULTURES PRIVATE LIMITED
# 34   U45200DD2010PTC004680        KARNAWAT INFRASTRUCTURES PRIVATE LIMITED
# 279  U67120DD1996PTC002008             KUNTAL SHAREBROKERS PRIVATE LIMITED
# 69   U52321DD1996PTC002009               DAYITA MERCANTILE PRIVATE LIMITED
# 2    L25209DD1992PLC009784                   TOKYO PLAST INTERNATIONAL LTD
# 3    L65923DD1994PLC009783                           TOKYO FINANCE LIMITED
# 247  U00329DD1975PLC000243                     REMS AUTO ENGINEERS LIMITED
# 232  U00200DD1975PTC000241           DAMAN AUTO INDUSTRIES PRIVATE LIMITED
# 310  U67120DD2000PLC004709                        TOTAL SECURITIES LIMITED
# 16   U51909DD2003PTC004684         TOTAL COMMODITIES (INDIA) PRIVATELIMITED
# 320  U51909DD2004PTC004752    TRADEBULLS COMMODITIES BROKING PRIVATELIMITED
# 324  U93000DD2009PTC004753           TRADEBULLS SECURITIES PRIVATE LIMITED
# 292  U65991DD2015PTC004763        CHANDARANA SHARES & STOCKS PRIVATELIMITED
# 287  U65999DD2015PTC004769           CHANDARANA SECURITIES PRIVATE LIMITED
# 313                              2016-03-31
# 314                              2016-03-31
# 315                              2016-03-31
# 301                              2014-03-31
# 305                              2014-03-31
#
#     LATEST BALANCE SHEET FILING FY END DATE
# 73                               2016-03-31
# 34                               2015-03-31
# 279                                       0
# 69                                        0
# 2                                2016-03-31
# 3                                2016-03-31
# 247                                       0
# 232                                       0
# 310                              2015-03-31
# 16                               2015-03-31
# 320                              2015-03-31
# 324                              2015-03-31
# 292                              2016-03-31
# 287                              2016-03-31
# 5                                2016-03-31
# 10                               2016-03-31
# 6                                2015-03-31
# 4                                2015-03-31
# 309                              2015-03-31
# 7                                2015-03-31
# 48                               2015-03-31
# 54                               2015-03-31
# 50                               2008-03-31
# 49                               2013-03-31
# 53                               2015-03-31
# 47                               2015-03-31
# 46                               2015-03-31
# 45                               2015-03-31
# 39                               2015-03-31
# 38                               2015-03-31
# 37                               2015-03-31
# 313                              2016-03-31
# 314                              2016-03-31
# 315                              2016-03-31
# 301                              2014-03-31
# 305                              2014-03-31

# %% [markdown]
# Duplicates in ```REGISTERED_OFFICE_ADDRESS``` do not mean duplicates in companies.
# Sometimes a very small NGO cannot afford their own office, and will register their non-profit under another existing one. Also, some companies that share an address are branches of the same company.

# %% [markdown]
# ### EMAIL_ID
# <a class="anchor" id="4.13"></a>
# Company email.

# %%
column = Daman_Diu_2016["EMAIL_ID"]
column
# Out:
# 0               darshanvoraandco@gmail.com
# 1                   jaindeepak13@gmail.com
# 2                     parul@tokyoplast.com
# 3              info.tokyofinance@gmail.com
# 4      sandeep.bhanushali@dolatcapital.com
#                       ...
# 322                viprittrading@yahoo.com
# 323    sandeep.bhanushali@dolatcapital.com
# 324               compliance@tradebulls.in
# 325                   cakartik85@gmail.com
# 326                 mkc_ca@youbroadband.in
# Name: EMAIL_ID, Length: 327, dtype: object

# %%
# Number of empty strings
print("Empty strings:", sum(column == " "))
# -1 from invalid value
print("No. of unique values:", len(column.unique()) - 1)

# Check for duplicates
counter = dict(Counter(column))
duplicates = { key:[value] for key, value in counter.items() if value > 1}
# Remove empty string duplicates
del duplicates[" "]
print("No. of Duplicates:", len(duplicates))

table = pd.DataFrame.from_dict(duplicates)
table = table.melt(var_name="Duplicate Email IDs", value_name="Count").sort_values(by=["Count"], ascending=False).reset_index(drop=True)
table
# Out:
# Empty strings: 87
# No. of unique values: 180
# No. of Duplicates: 30
#                     Duplicate Email IDs  Count
# 0     ipp.compliance@windworldindia.com     13
# 1   sandeep.bhanushali@dolatcapital.com      8
# 2           jyotsna.solse@cellopens.com      5
# 3    legal.compliance@windworldinda.com      5
# 4             khemani_ad1@sancharnet.in      4
# 5                  accounts@satec.co.in      3
# 6          affluence@affluencetrade.com      3
# 7   legal.compliance@windworldindia.com      3
# 8               alliedplastics@vsnl.com      3
# 9                    vyas4you@gmail.com      3
# 10                     nissans@vsnl.com      2
# 11       secretarial@quantcapital.co.in      2
# 12           csspl@chandaranaonline.net      2
# 13   sandeepbhanushali@dolatcapital.com      2
# 14              yatin@vijetabroking.com      2
# 15                ln1957@rediffmail.com      2
ATE_OF_REGISTRATION REGISTERED_STATE  Authorized Capital  (Rs.)  \
# 36           2013-10-12    Daman and Diu                     100000
# 44           2013-10-12    Daman and Diu                     100000
# 45           2013-10-12    Daman and Diu                     100000
# 46           2013-07-20    Daman and Diu                     100000
# 47           2013-05-21    Daman and Diu                     100000
# 48           2011-10-17    Daman and Diu                  150000000
# 49           2005-12-30    Daman and Diu                   65000000
# 50           2005-09-23    Daman and Diu                  160000000
# 52           2000-04-05    Daman and Diu                  400000000
# 53           2013-10-12    Daman and Diu                     100000
# 54           2009-11-12    Daman and Diu                 3600000000
# 55           2000-03-03    Daman and Diu                     100000
# 81           2006-02-07    Daman and Diu                   75000000
#
#      PAIDUP_CAPITAL (RS.)  PRINCIPAL_BUSINESS_ACTIVITY_CODE  \
# 36                 100000                             40200
# 44                 100000                             40108
# 45                 100000                             40108
# 46                 100000                             40108
# 47                 100000                             40108
# 48               22600000                             40108
# 49               65000000                             40108
# 50              160000000                             40108
# 52              400000000                             40108
# 53                 100000                             40102
# 54             3520000000                             40102
# 55                 100000                             40100
# 81               69000000                               432
#
#                             REGISTERED_OFFICE_ADDRESS  \
# 36  Plot No. 33, Unit-II, Silver Industrial Estate...
# 44  Plot No. 33, Daman Patalia Road,Bhimpore  Dama...
# 45  Plot No. 33, Daman Patalia Road,Bhimpore  Dama...
# 46  Plot No. 33, Daman Patalia Road,Bhimpore  Dama...
# 47  Plot No. 33, Daman Patalia Road,Bhimpore  Dama...
# 48  PLOT NO. 33, DAMAN PATALIA ROAD,BHIMPORE  DAMA...
# 49  PLOT NO. 33, DAMAN PATALIA ROAD,BHIMPORE, DAMA...
# 50  PLOT NO. 33, DAMAN PATALIA ROAD,BHIMPORE, DAMA...
# 52  PLOT NO.33,DAMAN PATALIA ROADBHIMPORE,  DAMAN ...
# 53  Plot No. 33, Daman Patalia Road,Bhimpore  Dama...
# 54  PLOT NO. 33, DAMAN PATALIA ROAD,BHIMPORE  DAMA...
# 55  33, DAMAN PATALIA ROAD,BHIMPORE, DAMAN  DAMAND...
# 81  PLOT NO. 33, DAMAN PATALIAROAD, BHIMPORE,DAMAN...
#
#                              EMAIL_ID LATEST ANNUAL REPORT FILING FY END DATE  \
# 36  ipp.compliance@windworldindia.com                              2015-03-31
# 44  ipp.compliance@windworldindia.com                              2015-03-31
# 45  ipp.compliance@windworldindia.com                              2015-03-31
# 46  ipp.compliance@windworldindia.com                              2015-03-31
# 47  ipp.compliance@windworldindia.com                              2015-03-31
# 48  ipp.compliance@windworldindia.com                              2015-03-31
# 49  ipp.compliance@windworldindia.com                              2012-03-31
# 50  ipp.compliance@windworldindia.com                              2008-03-31
# 52  ipp.compliance@windworldindia.com                                       0
# 53  ipp.compliance@windworldindia.com                              2015-03-31
# 54  ipp.compliance@windworldindia.com                              2015-03-31
# 55  ipp.compliance@windworldindia.com                              2013-03-31
# 81  ipp.compliance@windworldindia.com                              2012-03-31
#
#    LATEST BALANCE SHEET FILING FY END DATE
# 36                              2015-03-31
# 44                              2015-03-31
# 45                              2015-03-31
# 46                              2015-03-31
# 47                              2015-03-31
# 48                              2015-03-31
# 49                              2013-03-31
# 50                              2008-03-31
# 52                              2008-03-31
# 53                              2015-03-31
# 54                              2015-03-31
# 55                              2013-03-31
# 81                              2013-03-31

# %% [markdown]
# Many of the duplicates in ```EMAIL_ID``` are branches of the same company.

# %% [markdown]
# ### LATEST ANNUAL REPORT FILING FY END DATE
# <a class="anchor" id="4.14"></a>
# Latest annual report filing fiscal year end date.
